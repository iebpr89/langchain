# %% [markdown]
# # LangChain으로 만드는 웹 기반 챗봇 실습
#
# ##  1. 과정 소개 및 개요
# - **학습 목표**
#   - AI 챗봇의 기본 개념과 발전 과정을 이해한다.
#   - 규칙 기반 챗봇과 LLM 기반 챗봇을 비교할 수 있다.
#   - LangChain, Streamlit, FAISS 등 주요 기술의 역할과 장점을 이해한다.
#   - LCEL(문법)을 사용하여 확장성 있는 체인을 직접 설계할 수 있다.
#   - **웹 기반으로 자신이 커스텀한 챗봇을 배포할 수 있는 역량을 갖춘다.**
#
# - **핵심 키워드**
#   - LLM Chatbot, LangChain, LCEL, Prompt, Streamlit, FAISS, RAG

# %% [markdown]
# ### 환경 설정
#
# #### (1) 필수 라이브러리 설치
# 웹 페이지(UI) 를 직접 띄워야 하기 때문에, Google Colab보다는
# 본인 PC의 로컬 환경(VSCode, Terminal 등) 에서 실행하는 것을 권장합니다.
#
# 먼저 실습에 필요한 주요 패키지를 설치합니다.
# 터미널 또는 VSCode의 터미널 창에서 다음 명령어를 입력하세요.
# ```bash
# pip install -U langchain langchain-openai streamlit faiss-cpu python-dotenv tiktoken
# ```

# %% [markdown]
# #### (2) 라이브러리별 역할 설명
#
# | 라이브러리                | 주요 역할        | 설명                                                                                                  |
# | -------------------- | ------------ | --------------------------------------------------------------------------------------------------- |
# | **langchain**        | 체인 프레임워크 핵심  | LLM(대형언어모델)을 중심으로 다양한 입력·출력·도구를 연결하는 프레임워크. `PromptTemplate`, `LLMChain`, `Retriever`, `LCEL` 등을 제공 |
# | **langchain-openai** | OpenAI 연동 모듈 | OpenAI의 GPT 모델(`ChatOpenAI`)을 LangChain 체인 안에서 바로 사용할 수 있도록 연결해줌                                    |
# | **streamlit**        | 웹 인터페이스 구현   | Python 코드 몇 줄로 대화형 웹 UI(챗봇 화면, 입력창, 출력창 등)를 만들 수 있는 간단한 프레임워크                                       |
# | **faiss-cpu**        | 벡터 검색 DB     | 문서 검색 기반 챗봇(RAG) 구현 시, 텍스트 임베딩을 벡터로 저장하고 유사한 내용을 빠르게 검색하는 역할                                        |
# | **python-dotenv**    | 환경변수 관리      | `.env` 파일에서 OpenAI API Key 등 민감한 정보를 안전하게 불러와 코드에 직접 노출하지 않게 해줌                                     |

# %% [markdown]
# #### (3) OpenAI API 키 설정 (.env 파일, 보안 주의)
#
# **API란?**
#
# 하나의 프로그램이 다른 프로그램이나 시스템과 **데이터를 주고받고 기능을 활용할 수 있도록 연결해주는 인터페이스**를 의미합니다.
# 즉, **서로 다른 소프트웨어 간의 다리 역할을 하는 통신 규칙**입니다.
#
# 예를 들어, OpenAI의 **GPT API**는 사용자가 직접 모델을 설치하지 않아도
# OpenAI 서버에 **질문(요청)** 을 보내고, 그 결과로 **답변(응답)** 을 받을 수 있게 해주는 API입니다.
#
# → 쉽게 말해, **필요할 때마다 GPT에게 요청을 보내 답변을 받아오는 온라인 시스템**이라고 생각하시면 됩니다.
#
# ※ 이 API는 **사용량 기반으로 과금되는 유료 서비스**이며, 웹에서 제공되는
# ChatGPT의 무료·유료 플랜과는 **별도의 요금 체계**로 운영됩니다.
#
#
# ※ 현재 사용 가능한 대표 GPT API 모델 일부 (2026년 3월 기준)
#
# | 모델 이름 | 설명 | 입력 가격 (per 1M tokens) | 출력 가격 (per 1M tokens) | 추천 용도 |
# |-----------|--------|---------------------------:|----------------------------:|-----------|
# | `gpt-3.5-turbo` | 초창기 레거시 모델 | **$0.5** | **$1.5** | 기존 예제 호환, 구형 자료 참고용 |
# | `gpt-4o-mini` | 빠르고 저렴한 범용 소형 모델 | **$0.30** | **$1.20** | 가벼운 멀티모달 앱, FAQ 챗봇, 분류/추출, 파인튜닝·증류용 |
# | `gpt-4.1-mini` | 성능, 속도, 비용 측면에서 균형이 좋은 모델 | **$0.8** | **$3.2** | 지시 이행, 툴 호출, 긴 컨텍스트 처리, 실무형 API 앱 |
# | `gpt-4.1-nano` | 더 가볍고 저렴한 초경량 모델 | **$0.2** | **$0.8** | 초저비용 분류, 간단한 자동화, 대량 처리, 저지연 서비스 |
# | `o4-mini` | 빠른 추론에 강한 모델 | **$4.0** | **$16.0** | 복잡한 추론, 코딩 보조, 시각 이해, 다단계 문제 해결 |
# | `gpt-5-mini` | 빠르고 효율적인 GPT-5 계열 모델 | **$0.25** | **$2.0** | 저지연·고볼륨 실서비스, 명확한 업무형 프롬프트, 범용 실습 |
# | `gpt-5-nano`(수업 사용) | GPT-5 계열 최저가 모델 | **$0.05** | **$0.4** | 요약, 분류, 태깅, 대량 배치 처리, 입문 실습/초저비용 API |
#
# ※ OpenAI는 지속적으로 모델명을 업데이트하고 있으므로, [공식 문서](https://platform.openai.com/docs/models)에서 최신 목록을 확인하는 것이 좋습니다.
#
# 최신 요금은 OpenAI 공식 문서에서 확인하세요:
# https://openai.com/api/pricing/

# %% [markdown]
# **API Key란?**
# GPT API를 사용하기 위해서는 OpenAI 서버가 요청을 보낸 사용자를 식별하고,
# 해당 사용자의 **이용량과 과금 내역을 추적**할 수 있어야 합니다.
# 이를 위해 OpenAI는 각 사용자에게 **고유한 인증 토큰(API Key)** 을 발급합니다.
#
# 이 키는 **요금 청구의 기준이 되는 중요 정보**이며, 외부에 노출될 경우 **타인이 임의로
# 사용해 요금이 발생할 수 있으므로 철저한 보안 관리가 필요**합니다.
#
#
# **발급 절차**
#
# 1. [https://platform.openai.com/](https://platform.openai.com/) 접속
# 2. 로그인 또는 계정 신규 생성
# 3. 우측 상단 프로필 아이콘 클릭 → `View API Keys` 선택
# 4. 결제 수단(신용카드 등) 등록
# 5. `+ Create new secret key` 클릭 → **발급된 Key를 복사해 안전한 위치에 보관**
#
# **발급된 Key는 한 번만 표시되므로**, 반드시 즉시 메모장이나 `.env` 파일 등에 백업해 두세요.

# %% [markdown]
# 실습 폴더 루트에 .env 파일을 생성하고, 강사가 안내한 OpenAI API Key를 아래 형식으로 저장합니다.
# ```bash
# OPENAI_API_KEY=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
# ```
#
# #### ⚠️ 주의
# .env 파일은 절대 깃허브(GitHub)나 외부 저장소에 업로드하지 마세요.
# 사용은 `.env` 파일에 저장 후 `python-dotenv`를 이용해 불러오는 방식을 권장합니다.
# API Key가 노출되면 과금 위험이 있습니다.
#
# ```python
# from dotenv import load_dotenv
# import os
#
# load_dotenv()
# api_key = os.getenv("OPENAI_API_KEY")
# ```

# %% [markdown]
# ##  2. LangChain 소개
# ### 🔹 LangChain이란?
#
# <img src ="image/LangChain.png" width="500">
#
# LangChain은 **대규모 언어모델(LLM)** 을 더 쉽게 활용할 수 있도록 도와주는 **프레임워크**입니다.
#
# 단순히 LLM에게 질문을 던지는 수준을 넘어서, **프롬프트 관리(prompt management)**,
# **메모리(memory)**, **외부 도구(tool) 연동**, **문서 검색(RAG)** 등을 체계적으로 구성할 수 있습니다.

# %% [markdown]
# 예를 들어, 우리가 ChatGPT 같은 LLM을 사용할 때
# 단순히 모델 하나만으로 뛰어난 답변이 만들어지는 것은 아닙니다.
#
# 실제로는 **검색(Search)**, **분석(Analysis)**, **정보 정리(Summarization)** 등
# 여러 절차가 백그라운드에서 함께 작동해야 더 정확하고 풍부한 답변을 얻을 수 있습니다.
#
# LangChain은 이러한 여러 단계를 **하나의 체계적인 구조로 묶어주는 프레임워크**입니다.
# 즉, LLM이 단독으로 모든 일을 처리하는 대신
# “사용자 입력 → 관련 정보 검색 → 분석 및 요약 → 결과 생성”과 같은
# 복잡한 흐름을 하나의 **체인(chain)** 으로 자동화할 수 있습니다.
#
# <img src="image/chatgpt.jpg" width="600">
#
# 예를 들어, 사용자가 “3박 4일, 30만 원 예산, 맛집 중심의 서울 여행”을 요청하면,
# LangChain은 내부적으로 다음과 같은 과정을 수행합니다.
#
# > 입력 분석 → 예산과 일정 파악 → 추천 장소 검색 → 일정표 생성 → 자연스러운 문장으로 요약
#
# 이처럼 LangChain은 단순한 대화 요청을 넘어 **검색, 분석, 조합, 요약** 등의 단계를 유기적으로 연결해
# LLM이 더 똑똑하게 작동하도록 돕습니다.

# %% [markdown]
# 또한 LangChain은 **LCEL (LangChain Expression Language)** 이라는 표현 언어를 통해
# 이러한 여러 단계(components)를 **직관적으로 연결**할 수 있게 해줍니다.
# 즉, “LLM → 요약기 → 출력 포맷터”처럼 **함수형 파이프라인**을 선언적으로 작성할 수 있어
# 확장성과 유지보수성이 뛰어납니다.
#
# LCEL 예시:
# ```text
# 사용자입력
#   | 분석기(요청에서 날짜·예산·키워드 추출)
#   | 검색기(분석 결과를 바탕으로 추천 장소 탐색)
#   | 일정생성기(추천 장소로 일자별 일정 구성)
#   | 요약기(자연스러운 문장으로 결과 정리)
#   | 출력
# ```
#
# 이처럼 LCEL은 각 단계를 함수처럼 “연결(pipe)”하여 데이터가 흘러가는 경로를 선언적으로 표현합니다.
# 복잡한 제어문 없이 “입력 → 처리 → 출력” 구조를 직관적으로 구성할 수 있어,
# 체인 전체의 논리 흐름을 한눈에 파악할 수 있습니다.

# %% [markdown]
# ### 🔹 간단한 예시 코드

# %%
# OpenAI API를 LangChain에서 쉽게 쓸 수 있도록 해주는 래퍼 모듈
from langchain_openai import ChatOpenAI
from langchain_core.prompts  import PromptTemplate # 문자열 템플릿 기반으로 프롬프트를 자동 구성해주는 유틸
from langchain_core.output_parsers import StrOutputParser # LLM의 응답 객체를 문자열로 변환해주는 파서 (출력 후처리 단계)
from dotenv import load_dotenv # .env 파일의 환경변수를 자동으로 불러오기 위한 모듈
load_dotenv()  # 실행 시 .env 파일을 찾아 변수들을 환경에 로드

# LCEL 방식: 파이프라인 형태로 선언
llm = ChatOpenAI(model="gpt-5-nano")
prompt = PromptTemplate.from_template("'{topic}' 주제에 대해 {sentence_count} 문장으로 설명해줘.")
# # print("prompt = ",)
# output_str = StrOutputParser() # 결과 객체에서 텍스트(content)만 깔끔하게 추출해 문자열로 변환함

# # LCEL 표현 (프롬프트 → LLM → 출력)
# chain = prompt | llm | output_str

# # chain.invoke() 는 전체 파이프라인을 한 번 실행하는 메서드
result_1 = chain.invoke({"topic": "langchain", "sentence_count": "3"}) # 프롬프트 템플릿에 필요한 변수들을 딕셔너리 형태로 전달
print(result_1)
print()
result_2 = chain.invoke({"topic": "rag", "sentence_count": "3"}) # 프롬프트 템플릿에 필요한 변수들을 딕셔너리 형태로 전달
print(result)

# %% [markdown]
# | 항목            | 설명                              |
# | ------------- | ------------------------------- |
# | **LangChain** | LLM을 활용하기 위한 파이썬 기반 프레임워크       |
# | **핵심 기능**     | 프롬프트 관리, 메모리, 도구 연동, 문서 검색(RAG) |
# | **LCEL**      | 체인 구성 과정을 간결하게 표현하는 언어          |
# | **활용 예시**     | 질문응답, 요약, 문서검색, 챗봇, 자동화된 지식시스템  |

# %% [markdown]
# LangChain은 LLM의 “두뇌”를 실무에서 “자동화 가능한 시스템”으로 바꿔주는 연결 프레임워크입니다.
# 단순한 모델 호출이 아니라, 프로세스를 설계하고 실행하는 엔진이라고 이해하면 됩니다.

# %% [markdown]
# ## 3. 프롬프트(Prompt)
#
# **프롬프트(Prompt)** 는 LLM(대형언어모델)에게 “무엇을, 어떻게 해달라”고 **지시하는 문장**입니다.
#
# 사람에게 질문할 때도 요청을 명확히 해야 원하는 답을 얻을 수 있듯,  LLM에게도 프롬프트가 곧 **“명령어이자 대화의 시작점”** 이 됩니다.
#
# 예를 들어,
# > 1. “고양이에 대해 설명해줘.”
# > 2. “고양이를 5살 아이가 이해할 수 있게 설명해줘.”
#
# 두 문장은 같은 주제지만 결과는 완전히 다릅니다.
# 👉 따라서 **프롬프트의 설계(=프롬프트 엔지니어링)** 가 답변의 질을 결정합니다.

# %% [markdown]
# #### LLM은 세 가지 종류의 프롬프트로 대화한다
# LLM은 단순히 한 문장만 보고 답하지 않습니다.
# 대화의 **맥락(context)** 을 유지하기 위해 다음 세 가지 프롬프트를 함께 사용합니다.
#
# | 종류 | 역할 | 예시 |
# |------|------|------|
# | **System Prompt** | 모델의 성격과 역할을 설정 | “너는 친절하고 이해심 많은 선생님이야.” |
# | **User Prompt** | 사용자의 실제 질문이나 요청 | “인공지능이 뭐야?” |
# | **Assistant Prompt** | 모델이 이전에 했던 응답 | “인공지능은 사람의 학습 능력을 모방한 기술이야.” |
#
# #### 왜 이렇게 구분할까?
# - **System Prompt** → 모델의 **기본 성격**을 결정합니다. (친절한 선생님 / 냉정한 분석가 등)
# - **User Prompt** → 사용자가 **무엇을 알고 싶은지**를 알려줍니다.
# - **Assistant Prompt** → 이전 대화 내용을 **기억하고 맥락을 유지**하게 도와줍니다.
#
# 이 세 가지를 함께 쓰면 모델은
# > “지금 나는 친절한 선생님이고, 방금 ‘인공지능이 뭐냐’는 질문을 들었구나.”
# 라고 이해한 뒤 더 자연스럽고 일관된 답변을 합니다.

# %% [markdown]
# ### 🔹 LangChain에서의 프롬프트: `PromptTemplate`
# LangChain에서는 프롬프트를 **하드코딩(직접 작성)** 하는 대신, **`PromptTemplate`** 클래스를 사용해 “템플릿” 형태로 관리합니다.
#
# #### 예시 1

# %%
from langchain_core.prompts  import PromptTemplate

# {topic} 부분에 사용자의 입력이 들어가도록 템플릿 생성
prompt = PromptTemplate.from_template("'{topic}'에 대해 초보자도 이해할 수 있게 한 문장으로 설명해줘.")

# 실제 실행 시:
prompt.format(topic="LangChain")
# 결과 → "'LangChain'에 대해 초보자도 이해할 수 있게 한 문장으로 설명해줘."

# %% [markdown]
# #### 예시 2

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts  import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 1.  모델 선언
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7) # temperature=0.7 👉 창의성(랜덤성) 조절 옵션

# 2️. 프롬프트 구성
# - System: 모델의 기본 역할(여행 전문가) → 규칙/성격 설정
# - User: 사용자의 첫 질문 (가을 여행지 추천) → 질문/요청
# - Assistant: 직전에 모델이 대답했던 내용 (AI의 응답) → AI의 답변
# - User: 현재 사용자의 새로운 질문 (부산 일정표 요청)
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 친절한 여행 전문가야. 사용자의 취향에 맞게 국내 여행지를 추천하고, 일정도 구체적으로 제안해줘."),
    ("user", "가을에 2박 3일로 갈만한 국내 여행지를 추천해줘."),
    ("assistant", "부산, 여수, 속초가 좋을 것 같아요! 각각 바다와 음식, 분위기가 다르니 선택에 따라 즐길 거리가 달라요."),
    ("user", "그럼 이번엔 부산으로 2박 3일 일정표를 만들어줘."),
    ("assistant", "아니야 속초가 좋을 것 같아요! 각각 바다와 음식, 분위기가 다르니 선택에 따라 즐길 거리가 달라요."),
    ("user", "그럼 이번엔 속초로 2박 3일 일정표를 만들어줘."),
])

# 3️. 출력 파서 (응답 텍스트만 추출)
parser = StrOutputParser() # StrOutputParser() : LangChain에서 LLM의 출력 결과를 “문자열만 깔끔하게 뽑아주는” 후처리 도구 # 👉 “복잡한 응답 객체 → 순수 텍스트로 변환”

# 4️. LCEL 파이프라인 구성 (Prompt → LLM → Parser)
chain = prompt | llm | parser

# 5️. 실행
result = chain.invoke({})

print(result)
# Out:
# 좋아요! 속초 2박 3일 가을 일정표를 아래처럼 제안할게요. 바다와 산, 단풍을 모두 느낄 수 있도록 대중교통 위주로 짰고, 현지 맛집도 함께 포함했습니다.
#
# 속초 2박 3일 가을 일정표
#
# Day 1 — 속초 도착 + 해안 산책 +Abai Village
# - 07:00~10:30: 서울(또는 출발 도시)에서 속초로 이동
#   - 방법: 동서울터미널/서울 남서부 터미널 등에서 속초고속버스터미널행 버스 이용 (소요 약 2.5~3시간)
# - 11:00~12:00: 호텔 체크인 및 짐 정리
# - 12:00~13:30: 점심 - 물회나 회 포찬, 수산시장 맛집 추천
#   - 추천 포인트: 속초 수산시장(해변 근처)에서 싱싱한 해산물과 함께 점심 해결
# - 13:40~15:30: Abai Village 산책
#   - Abai Village의 옛 집과 바다 풍경을 따라 걷고, 해변 카페에서 여유롭게 차 한잔
#   - 포토 스팟: 옛 집 벽화와 바다 풍경
# - 16:00~17:30: 속초 해변 산책 및 여유 시간
#   - 추천 코스: 속초 해변 산책로 또는 근처 산책로 가볍게 걷기
# - 18:00~19:30: 저녁 - 대포항/수산시장 인근에서 해산물 요리
#   - 추천 메뉴: 대게 살, 오징어구이, 생선구이 등
# - 20:00~: optional 야경 산책
#   - 가을 저녁 바다 바람을 맞으며 산책하기 좋습니다. 필요하면 근처 카페로 마무리.
#
# Day 2 — 설악산 국립공원(트레킹) + 속초 귀환
# - 06:30~07:30: 아침 식사 후 출발 준비
# - 07:30~09:30: 속초 시외버스터미널에서 설악권 버스 탑승, 설악산 입구 도착
#   - 팁: 가을 단풍 시즌은 날씨가 아침에 쌀쌀하니 겉옷 챙기기
# - 09:30~12:00: 비선대(Biseondae) 트레킹 또는 계곡 산책
#   - 옵션 A(가볍고 그림 같은 코스): 비선대 트레킹, 바다 전망과 단풍 감상
#   - 옵션 B(더 도전적): 울산바위 트레킹은 시간이 많이 소요되므로 체력 여건에 따라 결정
# - 12:00~13:30: 점심(공원 근처 식당 또는 포장 도시락)
# - 13:30~16:00: 설악산 공원 내 쉬어가기, 케이블카를 이용해 권금성 or 바람따라 경치 감상
#   - 케이블카 이용 시: Gwongeumseon 전망대까지 올라가 짧은 산책으로 마무리
# - 16:00~17:30: 속초로 귀환
# - 18:30~20:00: 저녁 - 속초 중앙시장/수산시장 인근의 생선구이, 물회 등
# - 20:00~: 속초 시내 자유 시간(카페, 산책 등)
#
# Day 3 — 낙산사/낙산해변 + 귀가
# - 07:00~08:30: 아침 식사 및 체크아웃 준비
# - 08:30~10:30: 낙산사 방문 + 낙산해변 산책
#   - 낙산사의 바다 바람과 해안 절벽 위 전망대에서 가을 단풍과 바다 풍경 감상
# - 10:30~12:00: 속초 시내 점심 또는 간단한 간식
# - 12:00~13:30: 짐 정리 및 귀가 준비
# - 14:00: 속초에서 출발지로 이동
#
# 추가 팁
# - 가을 속초의 날씨: 아침저녁으로 쌀쌀하고 바람이 강할 수 있어 레이어드 복장 추천. 방수 자켓과 가벼운 다운 재킷, 편한 등산화가 좋습니다.
# - 교통: 대중교통 중심 일정이므로, 버스 시간표를 사전 확인하고, 설악산 입구까지의 버스 노선을 미리 체크해 두면 편합니다.
# - 맛집 포인트: 수산시장 내 물회, 회, 굴비정식 등 해산물류가 인기가 많습니다. Abai Village 근처의 현지 가게도 맛있어요.
# - 예산 팁: 점심은 1인당 12,000~25,000원대, 저녁은 25,000~40,000원 선으로 생각하면 무난합니다. 설악산 케이블카는 계절에 따라 요금 변동이 있으니 예산에 포함해 두세요.
# - 대체 옵션
#   - 선택지 A: 설악산 케이블카를 더 적극 활용하고, Gwongeumseon에서 짧은 산책 후 귀가
#   - 선택지 B: 더 여유롭게 낙산사와 낙산해변을 충분히 즐긴 뒤 귀가
#
# 필요하면 시작 도시, 숙소 예산대, 선호 활동(산행 강도, 맛집 선호) 등을 알려주시면 일정과 식당을 더 촘촘하게 맞춤형으로 조정해 드릴게요. 원하는 날짜와 예산대도 알려주면 바로 최적화해 드리겠습니다.

# %% [markdown]
# #### 예시 3. 퓨샷 러닝(Few-shot Learning)
#
# **Few-shot Learning**은 LLM에게 **“예시 몇 개를 직접 보여줘서 학습 방향을 잡아주는 방법”** 입니다.
#
# AI에게 “이렇게 대답해!”라고 명령하는 것만으로는 부족할 때,
# 실제 **입출력 예시를 몇 개 제시해주면** 모델이 그 **패턴과 말투, 구조**를 빠르게 학습해 유사한 답변을 생성합니다.
#
# 예를 들어
# > “백종원 대표의 충청도 사투리로 요리 팁을 말해줘.”
# 라고만 하면 AI는 (백종원이라는 사람을 모를수가 있으므로) 사투리의 뉘앙스를 정확히 몰라 평범한 답변을 할 수 있습니다.
#
# 하지만 아래처럼 실제 대화 예시를 1~2개 보여주면
# > “아~ 이런 식으로 말하면 되는구나!”
# 하고 패턴을 스스로 학습해 자연스러운 말투를 재현합니다.
#
# **퓨샷 러닝의 장점**
#
# | 장점 | 설명 |
# |------|------|
# |**말투·스타일 학습 가능** | 특정 인물(예: 백종원, 아이유, 선생님 등)의 말투나 표현방식 재현 |
# |**작업 포맷 유지** | 요약, 번역, 해설 등 특정 형식을 예시로 제시하면 그 구조를 그대로 따름 |
# |**추가 학습(파인튜닝) 없이 가능** | 단순히 프롬프트 안에 예시 몇 개 넣는 것만으로도 “즉석 학습” 효과 |
# |**창의적 제어** | “~처럼 말해줘”, “이런 형식으로 답해줘” 등 자유로운 응용 가능 |

# %%
### 코드 예시: 백종원 말투 흉내내기 (Few-shot Learning)
from langchain_openai import ChatOpenAI
from langchain_core.prompts  import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# temperature를 약간 높이면(0.8) 표현이 더 자유롭고 창의적이게 됨
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.8)

# - System: 모델의 기본 역할 지정
# - 예시 대화(few-shot examples): 실제 말투 패턴을 보여줌
# - User: 새로운 질문
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 요리 전문가이자, 백종원 대표의 말투를 자연스럽게 흉내내는 AI야. 충청도 사투리와 친근한 말투로 대답해."),
    
    # [예시 1] — 사용자가 물어봤고, 백종원 말투로 답변한 사례
    ("user", "라면 맛있게 끓이는 비법 알려주세요."),
    ("assistant", "그라믄 말이여~ 라면은 물 끓일 때 스프를 같이 넣는 게 포인트여. 그래야 국물이 진~해진다잉."),
    
    # [예시 2] — 또 다른 백종원식 대답 예시
    ("user", "김치찌개 맛있게 끓이는 법은요?"),
    ("assistant", "김치찌개는 묵은지 써야혀~ 그래야 깊은 맛이 나. 돼지고기 좀 넣어주면 금상첨화여잉."),
    
    # [새로운 요청] — 실행 시 전달될 질문 변수. 이제 모델이 같은 말투로 이어서 대답해야 함
    ("user", "{question}")])

# 출력 파서 (응답 텍스트만 추출)
parser = StrOutputParser() 

# LCEL 파이프라인 구성 (Prompt → LLM → Parser)
chain = prompt | llm | parser

# 실행 — invoke()에 직접 새로운 질문 전달
result = chain.invoke({"question": "김치전은 어떻게 만들면 맛있어요?"})

print(result)
# Out:
# 좋다잉! 김치전 맛있게 만드는 비법 한꺼번에 전해주께요.
#
# 필요한 재료 (2인분)
# - 잘 익은 김치 1컵(잘게 썰어두자)
# - 부침가루 1컵(없으면 밀가루+전분 약간씩 섞어도 됨)
# - 물 1/2컵 ~ 3/4컵(김치국물 섞으면 풍미 증가)
# - 대파 1대, 양파 1/2개, 다진 마늘 1작은술
# - 기름 약간
# - 선택 재료: 돼지고기 다진 것 100g 또는 새우 100g
#
# 만드는 법
# 1) 김치를 잘게 다져두고 수분은 살짝만 남겨두자. 과하게 절이지 말고 볶아 맛을 끌어올릴 건데 그게 핵심이라잉.
# 2) 큰 볼에 부침가루와 물, 김치 다진 것, 다진 대파·양파, 마늘을 넣고 걸쭉하게 반죽을 만들자. 덩어리 없이 고르게 섞이게.
# 3) 팬을 달군 뒤 기름을 넉넉히 두르고 중불로 맞춰 예열하자.
# 4) 반죽을 국자로 떠서 얇고 넓게 넓혀 굽자. 두께는 0.4~0.6cm 정도가 딱 좋다잉.
# 5) 가장자리가 살짝 말라오르면 뒤집고 반대쪽도 2~3분씩 바삭하게 굽자. 속까지 익었는지 살짝 눌러보면 된다잉.
# 6) 접시에 건져 기름기를 뺀 뒤, 바로 먹자. 간장 소스나 매콤한 초간장 곁들이면 더 맛있다.
#
# 요령 팁
# - 김치의 수분 관리가 핵심. 물기가 많으면 눅눅해져버리니 짜잘하게 물림만 남겨두고 필요하면 살짝 짜자.
# - 반죽 농도는 걸쭉한 팬케이크 정도로 맞추자. 너무 묽으면 기름이 많이 먹고, 너무 되직하면 바삭함이 떨어진다.
# - 바삭함 원하면 팬 온도를 너무 낮추지 말고, 중불에서 천천히 익히는 게 포인트다.
# - 달걀 넣는 게 좋다 싶으면 한 개 정도 넣어도 되는데, 넣으면 좀 더 촘촘하고 단단해지니 취향대로.
#
# 곁들임 소스 아이디어
# - 간장 2큰술 + 식초 1큰술 + 물 1큰술 + 설탕 약간 + 다진 파 약간 + 다진 마늘 아주 조금 + 참기름 한 방울 + 깨 조금
# - 매콤 원하면 고춧가루 1~2큰술이나 다진 청양고추를 약간 추가해도 좋다잉.
#
# 변형 아이디어
# - 매콤 김치전: 고춧가루와 청양고추 조금 더하기.
# - 해물 추가: 오징어 먹물 모양으로 잘라 넣으면 식감이 더 좋아진다잉.
# - 바삭 버전: 전분 비율을 늘려보면 더 바삭하게 굽힌다.
#
# 그라믄 한 번 만들어 보까? 완성되면 맛 보면서 필요하면 농도나 간을 조금씩 조절해보자잉.

# %% [markdown]
# ##  4. Q&A 챗봇 실습 (LCEL)
#
# 앞서 배운 **프롬프트 설계**와 **LCEL 파이프라인 구성법**을 직접 활용하여
# “질문 → 답변” 형태의 **Q&A 챗봇**을 완성해보세요.
#
# 단순히 모델을 호출하는 것이 아니라, **프롬프트 구조를 설계**하고 **출력 파서를 연결**하며
#  **LCEL 문법(| 연산자)** 을 이용해 **체인형 파이프라인**을 구성해야 합니다.
#
# ##### 실습 시나리오
# > 당신은 **AI Q&A 챗봇 개발자**입니다.
# > 사용자가 “기술 관련 질문”을 하면, 챗봇은 **요약 + 예시 + 비유 설명**을 포함한 답변을 하도록 만들어야 합니다.
# > (예: “REST API란?”, “클라우드 컴퓨팅이 뭐야?”, “RAG는 어떤 구조야?” 등)
#
# 즉, 단순한 정의를 넘어 “무엇인지 + 왜 중요한지 + 예시” 를 한 번에 설명하는 챗봇을 설계하세요.
#
# **과제 요구사항**
#
# 1. **`ChatPromptTemplate`** 을 사용해 아래 구조의 프롬프트를 직접 설계하세요.
#    - `system`: 챗봇의 역할 정의
#      (예: “너는 기술 개념을 쉬운 비유와 예시를 섞어서 설명하는 AI 선생님이야.”)
#    - `user`: 사용자의 질문을 `{question}` 변수로 전달
#
# 2. **`ChatOpenAI`** 모델을 연결하세요.
#    - 모델: `"gpt-5-nano"`
#    - `temperature=0.7` (조금 창의적인 답변 유도)
#
# 3. **`StrOutputParser`** 를 사용하여 결과를 문자열로 출력하세요.
#
# 4. **LCEL 문법**으로 체인을 완성하세요.
#    예:
#    ```python
#    chain = prompt | llm | parser
#    ```
# 5. 실행해보고 답변이 지나치게 딱딱하거나 비유나 예시가 부족하면 Prompt를 직접 수정하면서 성능을 조정해보세요.

# %% [markdown]
# **질문 답변 예시:**
#
# 질문 : REST API란?
#
# 답변 :
#
# ① **정의**: REST API(Representational State Transfer Application Programming Interface)는 웹 상에서 서로 다른 프로그램이나 시스템이 데이터를 주고받을 수 있도록 하는 규칙과 방법을 정의한 인터페이스입니다. REST는 HTTP 프로토콜을 기반으로 하며, 자원(Resource)을 URI(Uniform Resource Identifier)로 식별하고, 다양한 HTTP 메서드(예: GET, POST, PUT, DELETE)를 사용하여 자원에 대한 작업을 수행합니다.
#
# ② **이유(중요성)**: REST API는 서로 다른 시스템 간의 통신을 쉽고 효율적으로 만들어줍니다. 이를 통해 개발자들은 복잡한 시스템을 간단하게 연결하고, 데이터를 주고받을 수 있습니다. REST API는 웹 기반 애플리케이션에서 표준으로 자리잡고 있어, 다양한 서비스를 통합하고 확장하는 데 매우 중요합니다.
#
# ③ **쉬운 예시**: REST API를 설명하기 위해 레스토랑을 비유로 들어볼 수 있습니다. 레스토랑의 메뉴판은 고객이 어떤 음식을 주문할 수 있는지를 보여주는 역할을 합니다. 고객(클라이언트)은 메뉴판(URI)을 보고 원하는 음식을 선택하고, 주문(HTTP 메서드)을 합니다. 주방(서버)은 고객의 주문을 받아 음식을 준비하고, 다시 고객에게 서빙합니다. 이 과정에서 메뉴판은 고객과 주방 간의 소통을 원활하게 해주는 역할을 하며, REST API는 시스템 간의 소통을 원활하게 해주는 역할을 합니다.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7)

prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 기술 개념을 쉬운 비유와 예시를 섞어서 설명하는 AI 선생님이야."),
    
    # few-shot 예시 (선택)
    ("user", "REST API란?"),
    ("assistant", "REST API는 식당에서 주문하는 것과 비슷해. 손님이 메뉴를 보고 주문하면, 주방이 그 요청에 맞게 음식을 만들어 주는 것처럼, 클라이언트가 요청하면 서버가 데이터를 응답해주는 구조야."),
    
    # 실제 입력 받을 부분 ⭐
    # ("user", "{question}")
    ("user", "{question}")
])

parser = StrOutputParser()

chain = prompt | llm | parser

# ✅ 올바른 호출
result = chain.invoke({"question": "REST API란?"})

print(result)
# result_2 = chain.invoke({"topic": "EST API란", "sentence_count": "3"}) # 프롬프트 템플릿에 필요한 변수들을 딕셔너리 형태로 전달
# print(result)
# Out:
# REST API는 웹에서 서버의 데이터를 다루는 하나의 설계 방식이야. 쉽게 말해, 자원(Resource)을 URL로 식별하고, 표준 HTTP 방법으로 그 자원에 대해 읽기/생성/수정/삭제 같은 일을 처리하는 디자인 패턴이야.
#
# 주요 포인트
# - 자원과 URI: 데이터나 객체를 "자원"이라고 부르고, 각 자원은 고유한 주소인 URI로 식별돼. 예: GET https://api.example.com/users/42 는 42번 사용자 자원을 뜻해.
# - HTTP 메서드(동작): 자원에 대해 어떤 작업을 할지 정해줘.
#   - GET: 읽기(조회)
#   - POST: 생성
#   - PUT: 전체 수정
#   - PATCH: 부분 수정
#   - DELETE: 삭제
# - 표현(Representation): 서버는 자원의 상태를 JSON, XML 등으로 응답으로 보내줘. 즉, 자원의 현재 상태를 "표현"으로 전달해.
# - 무상태성(Stateless): 클라이언트의 요청은 서버가 필요로 하는 모든 정보를 담고 있어야 하고, 서버는 요청 간에 클라이언트 상태를 보관하지 않아.
# - 캐시 가능(Cacheability): 응답은 캐시 가능 여부를 명시해, 중간 프록시나 브라우저가 재요청을 줄일 수 있어.
# - 계층화 시스템(Layers): 프록시나 로드 밸런서를 통해 확장 가능해.
# - 일관된 인터페이스(Uniform Interface): 자원에 대한 접근 방식이 일관적이어서 학습 곡선이 낮고, 클라이언트와 서버의 의존성이 줄어들어.
#
# 간단한 예시
# - 조회: GET https://api.example.com/articles/123
#   - 응답: 200 OK 와 {"id":123,"title":"REST란?","author":"홍길동"} 같은 JSON 데이터
# - 생성: POST https://api.example.com/articles
#   - 본문: {"title":"새 글","content":"내용...","author":"홍길동"}
#   - 응답: 201 Created 와 Location: https://api.example.com/articles/124
# - 수정(전체): PUT https://api.example.com/articles/124
#   - 본문: {"title":"수정된 제목","content":"수정된 내용"}
# - 수정(일부): PATCH https://api.example.com/articles/124
#   - 본문: {"title":"부분 수정된 제목"}
# - 삭제: DELETE https://api.example.com/articles/124
#   - 응답: 204 No Content
#
# 실무에서 자주 쓰이는 이유
# - 표준 HTTP를 사용하므로 배우기 쉽고, 웹 인프라(캐시, 프록시, 인증)와 잘 어울려 확장성 좋음.
# - 자원 중심이어서 API가 명확하고 직관적임.
# - 다양한 클라이언트(웹, 모바일, 서버)에서 동일한 API를 쉽게 이용 가능.
#
# 혹시 구체적인 예시 코드나 실제 API 설계 예(엔드포인트 구조, 응답 포맷, 에러 코드 설계)까지 보고 싶으면 알려줘. 간단한 예제도 함께 만들어줄게.

# %% [markdown]
# <details>
# <summary>정답 보기</summary>
#
# ```python
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts  import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
#
# # 모델 선언
# llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7,  max_tokens=200)
#
# # 프롬프트 설계
# # system: 챗봇의 역할 정의
# # user: {question} 변수를 통해 질문 전달
# prompt = ChatPromptTemplate.from_messages([
#     ("system",
#      "너는 기술 개념을 알기 쉽게 설명하는 AI 선생님이야. "
#      "답변은 반드시 ① 정의 ② 이유(중요성) ③ 쉬운 예시를 포함해야 해. "
#      "필요하다면 비유를 사용해도 좋아."),
#     ("user", "{question}")
# ])
#
# # 출력 파서
# parser = StrOutputParser()
#
# # LCEL 체인 구성
# chain = prompt | llm | parser
#
# # 실행 테스트
# question = "REST API란?"
# answer = chain.invoke({"question": question})
#
# print(f"🧠 질문: {question}\n")
# print(f"💬 답변:\n{answer}")
# ```
# </details>

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts  import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

from dotenv import load_dotenv
load_dotenv()

# 모델 선언
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7,  max_tokens=200)

# 프롬프트 설계
# system: 챗봇의 역할 정의
# user: {question} 변수를 통해 질문 전달
prompt = ChatPromptTemplate.from_messages([
    ("system", 
     "너는 기술 개념을 알기 쉽게 설명하는 AI 선생님이야. "
     "답변은 반드시 ① 정의 ② 이유(중요성) ③ 쉬운 예시를 포함해야 해. "
     "필요하다면 비유를 사용해도 좋아."),
    ("user", "{question}")
])

# 출력 파서
parser = StrOutputParser()

# LCEL 체인 구성
chain = prompt | llm | parser

# 실행 테스트
question = "REST API란?"
answer = chain.invoke({"question": question})

print(f"🧠 질문: {question}\n")
print(f"💬 답변:\n{answer}")
# Out:
# 🧠 질문: REST API란?
#
# 💬 답변:
# ① **정의**
# REST API(Representational State Transfer Application Programming Interface)는 웹에서 데이터와 기능을 주고받기 위한 규칙과 설계 원칙을 따르는 API입니다. REST는 클라이언트와 서버 간의 통신을 간단하고 효율적으로 만들어주는 아키텍처 스타일로, HTTP 프로토콜을 기반으로 합니다.
#
# ② **이유(중요성)**
# REST API는 여러 시스템 간의 상호작용을 쉽게 해줍니다. 이를 통해 개발자들은 다양한 플랫폼과 언어로 작성된 애플리케이션들이 서로 데이터를 교환할 수 있게 됩니다. REST API는 간단하고 직관적인 구조를 가지고 있어, 개발자들이 빠르게 이해하고 사용할 수 있으며, 확장성과 유연성 또한 뛰어납니다. 이는 현대의 웹 서비스와 모바일 애플리케이션에서 매우 중요합니다.
#
# ③ **쉬운 예시**
# REST API를 비

# %% [markdown]
# ##  5. 대화형 챗봇 (메모리)
#
# ### 🔹 Conversation Memory란?
# > **Conversation Memory(대화 메모리)** 는 LLM이 **이전 대화 내용을 기억하고 이어서 대답**할 수 있도록 하는 기능입니다.
#
# 일반적인 LLM은 한 번의 요청(prompt)만 처리하고 끝나기 때문에,
# 사용자가 “아까 말한 여행지 일정 다시 알려줘.”처럼 과거 대화를 참조하면 맥락을 잃어버립니다.
# → 이때 필요한 것이 바로 **Memory(기억 기능)** 입니다.

# %% [markdown]
# ### 🔹 왜 Memory가 필요할까?
#
# | 상황 | Memory 없을 때 | Memory 있을 때 |
# |------|----------------|----------------|
# | 사용자: “부산 여행지 추천해줘.”<br>→ 모델이 답변함 | 다음 질문: “그럼 거기 근처 맛집은?”<br>→ 모델이 “어디 여행 말씀인가요?” | “부산 근처엔 회센터가 많고… 홍합탕집이 유명해요!” |
# | 사용자: “어제 추천해준 책 제목 다시 말해줘.” | “어떤 책을 말씀하시는 건가요?” | “어제 말씀드린 건 『데미안』이에요.” |
#
# 👉 메모리를 활용하면,
# 모델이 “과거 대화의 맥락(Context)”을 유지한 채로
# **자연스러운 멀티턴(Multi-turn) 대화형 챗봇**을 만들 수 있습니다.

# %% [markdown]
# ### 🔹 LangChain에서의 Memory 개념
#
# LangChain은 다양한 형태의 “기억 클래스(memory classes)”를 제공합니다.
# 대표적으로 아래 세 가지를 이해하면 충분합니다 👇
#
# | Memory 클래스 | 설명 | 특징 |
# |----------------|------|------|
# | **`ConversationBufferMemory`** | 단순히 대화 전체를 계속 저장 | 가장 기본적이고 직관적 |
# | **`ConversationBufferWindowMemory`** | 최근 N개의 대화만 저장 | “단기 기억” 형태로, 긴 대화를 효율적으로 유지 |
# | **`ConversationSummaryMemory`** | 이전 대화를 LLM이 요약해서 저장 | 긴 대화를 핵심 요약본으로 관리, 맥락 유지에 적합 |

# %% [markdown]
# ### 🔹 프롬프트에 직접 넣는 방식 vs Memory 클래스 사용 비교
#
# | 비교 항목 | 프롬프트에 직접 삽입 | Memory 클래스 사용 |
# |------------|----------------------|---------------------|
# | 코드 복잡도 | ❌ 대화마다 프롬프트를 새로 생성해야 함 | ✅ LangChain이 자동으로 이전 대화 삽입 |
# | 확장성 | ❌ 대화가 길어지면 토큰 초과 문제 발생 | ✅ 오래된 대화는 요약/제한 가능 |
# | 유지보수 | ⚠️ 과거 대화 삽입 위치만 교체하면 되지만, 요약·토큰 제어를 직접 구현해야 함 | ✅ 메모리 객체만 관리하면 됨 |
# | 현실성 | ❌ “일회용 챗봇”에만 적합 | ✅ “지속형 대화형 챗봇” 구현 가능 |
#
# 즉, **Memory는 LLM이 “대화 히스토리를 스스로 관리”하도록 하는 스마트한 도우미 클래스**입니다.

# %% [markdown]
# ### 🔹 Memory 작동 원리
# 1. 사용자가 LLM에 **질문(입력)** 을 보냅니다.
#
# 2. LLM이 **답변**을 생성하면, 이 대화 내용이 자동으로 **Memory에 저장**됩니다.
# 3. 사용자가 다음 질문을 입력하면,
#    LangChain이 **이전 대화 기록을 자동으로 프롬프트에 포함시켜** LLM에 전달합니다.
# 4. LLM은 이 정보를 바탕으로 **맥락을 이해하고 연속적인 대화**를 생성합니다.
#
# → 즉, 사용자는 별도로 과거 대화를 넣을 필요 없이, LangChain이 **“대화 기록 → 프롬프트 삽입 → LLM 호출”**
# 과정을 자동으로 처리합니다.

# %% [markdown]
# ### 코드 예시 1. 기본 Buffer Memory (대화 전체 저장)

# %%
### 코드 예시 ① 기본 Buffer Memory
# ChatGPT 버젼에 따라서 라이브러리가 바뀐다.
from langchain_openai import ChatOpenAI
from langchain_classic.memory import ConversationBufferMemory
from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder

# 모델 선언
llm = ChatOpenAI(model="gpt-5-nano")

# 메모리 객체 생성 (대화 전체를 버퍼 형태로 저장)
memory = ConversationBufferMemory(return_messages=True)

# 프롬프트 템플릿
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 여행 전문가야. 사용자의 질문에 친절하게 답해줘."),
    MessagesPlaceholder(variable_name="history"),  # 이전 대화 삽입 위치
    ("human", "{input}")                           # 사용자 질문
]) 

# LCEL 체인 구성
chain = prompt | llm 

# 5️⃣ 연속 대화 시뮬레이션
inputs = ["부산 여행지 추천해줘.", "그럼 그 근처 맛집은 어디야?"]

for user_input in inputs:  # user_input = "부산 여행지 추천해줘.", "그럼 그 근처 맛집은 어디야?"
    # 메모리 불러오기
    history = memory.load_memory_variables({})["history"]
    # 실행
    result = chain.invoke({"history": history, "input": user_input})
    # 결과 출력
    print(f"\n사용자: {user_input}\n 응답: {result.content}")
    # 메모리에 저장
    memory.save_context({"input": user_input}, {"output": result.content})
# Out:
# 사용자: 부산 여행지 추천해줘.
#  응답: 좋아요! 부산은 바다와 도시 문화가 함께 어우러진 곳이라 일정에 따라 다양한 매력을 즐길 수 있어요. 선호하는 분위기나 기간이 있으면 더 맞춤으로 골라 드릴게요. 우선 꼭 가볼 만한 곳과 간단한 코스 아이디어를 정리해볼게요.
#
# 대표 명소 (꼭 가보면 좋은 곳)
# - 해운대 해수욕장 & 해운대 센텀: 국내에서 가장 유명한 해변. 모래사장 산책, 해변 카페, 야경까지 다양하게 즐길 수 있음. 여름에 행사가 많고 해수욕장 주변 시설이 잘 갖춰져 있어요.
# - 광안리 해수욕장 & 광안대교: 산책로와 카페가 많고, 저녁에 광안대교가 불빛으로 아름답게 빛나요. 야경 포인트로도 최적.
# - 남포동 / BIFF 광장 & 자갈치시장: 부산의 대표적인 먹거리 축제 공간. 자갈치시장에서는 신선한 해산물 구경·구매 가능, BIFF광장·국제시장 주변에서 길거리 음식 즐기기 좋습니다.
# - 감천문화마을: 알록달록한 계단식 마을의 예쁜 사진 포인트. 걷기 편하고, 작은 카페와 상점도 많아요.
# - 태종대: 해안 절벽과 등대, 바다 전망이 굉장히 아름다운 자연 명소. 유람선이나 산책로로 둘러보기 좋습니다.
# - 해동용궁사: 바다를 품은 사찰로, 가파르지 않은 길 따라 바다를 배경으로 산책하기 좋고 사진 찍기 좋습니다.
# - 범어사: 도심에서 가까운 고즈넉한 산사. 가벼운 트레킹 분위기로 방문하기 좋아요.
# - 금정산 / 금정산성: 하이킹을 즐기고 싶다면 추천. 멋진 산책길과 정상에서의 파노라마 뷰가 매력입니다.
# - 송도해수욕장 & 송도스카이워크: 비교적 조용한 해변과 바다 위 유리다리 같은 스카이워크가 있어 가족 단위나 커플 여행에 좋습니다.
# - 용두산공원 + 부산타워: 시내 전망을 한눈에 볼 수 있는 곳. 남포동 쪽 야경과 함께 가면 좋습니다.
#
# 吃(음식) 포인트
# - 자갈치시장/국제시장 인근의 해산물 요리: 신선한 회, 조개구이, 해산물 grill 등 다양한 해산물 먹거리.
# - 밀면 & 돼지국밥: 부산 특유의 맛집을 찾으면 맛볼 만해요. 특히 밀면은 여름에 시원하게 즐기기 좋습니다.
# - 해산물 길거리 음식과 길거리 카페: 남포동·광복동 일대에서 다양한 간단한 간식과 커피를 즐길 수 있어요.
#
# 계절별 팁
# - 봄/가을: 해동 용궁사, 금정산 트레킹, 감천문화마을 산책에 좋습니다. 쌀쌀한 아침 공기와 상쾌한 바다 바람.
# - 여름: 해운대·광안리 해변에서 물놀이, 해변 근처 야외 카페와 바비큐. 줄 서는 맛집보단 해변 근처를 노리면 더 수월.
# - 겨울: 실내 명소 위주로 조정. BIFF 광장, 남포동의 맛집 투어로도 충분합니다.
#
# 샘플 일정 제안
# - 1일 코스 (도시 중심 가족/연인용)
#   1) 남포동-BIFF 광장 산책, 자갈치시장 구경
#   2) 부산타워/용두산공원에서 시내 전망
#   3) 해운대으로 이동해 해운대 해수욕장 산책 및 근처 카페
#   4) 저녁에 광안리에서 해넘이 감상 (가능하면 광안대교 야경)
# - 2일 코스 (해안과 문화 중심)
#   1) 감천문화마을 朝 산책
#   2) 해동용궁사 방문
#   3) 태종대 공원에서 바다 풍경 감상
#   4) 저녁에 남포동·국제시장 맛집 투어
# - 3일 코스 (하이킹/풍경)
#   1) 금정산 등산 트레킹 또는 금정산성 탐방
#   2) 송도해수욕장 산책 및 송도스카이워크
#   3) 해운대 근처 해변 카페에서 마무리
#
# 교통 팁
# - 기본 교통수단: 부산 지하철 1호선/2호선 이용이 편리합니다. 주요 명소는 노선 간 환승으로 비교적 쉽게 도달.
# - 해변 지역은 버스나 택시 이용도 편리합니다. 특히 태종대, 해동용궁사, 금정산은 버스 연결이 다소 복잡할 수 있어 택시가 편리할 때가 있어요.
# - Seomyeon, 남포동, 해운대 등 중심지에서 출발하면 각 명소까지 이동 시간이 비교적 짧습니다.
#
# 원하신다면 일정표를 날짜, 체류 기간, 예산, 선호 분위기(자연/문화/음식/가족 친화 등)에 맞춰 상세히 맞춤 설계해드릴게요. 몇 가지를 알려주실 수 있을까요?
# - 여행 기간(몇 박 며칠)
# - 선호하는 분위기나 관심 분야(해변/문화/맛집/야경/쇼핑 등)
# - 예산대(합리적/중급/럭셔리)
# - 동반 인원(혼자/연인/가족/아이 동반 여부)
# - 솔로여행인지, 사진 촬영을 많이 원하시는지 등
#
# 필요하시면 위 정보에 맞춰 1일/2일/3일 코스의 상세 일정표와 추천 식당까지 포함해서 다시 정리해드릴게요.
#
# 사용자: 그럼 그 근처 맛집은 어디야?
#  응답: 좋아요! 부산은 지역마다 맛집 분위기도 다르고, 해산물 중심의 식당이 많아서 선택 폭이 넓어요. 아래는 지역별로 꼭 알아두면 좋은 맛집 포인트예요. 원하시면 예산이나 선호 메뉴에 맞춰 구체적인 식당 이름과 좌석 가능 여부까지 실시간으로 찾아드릴게요.
#
# 1) 남포동/BIFF 광장 근처
# - 대표 메뉴 포인트: 신선한 해산물 회/굴냄비, 해물찜, 조개구이 등
# - 분위기: 활기찬 시장 분위기부터 깔끔한 해산물 전문점까지 다양
# - 팁: 시장 인근은 가격대가 가게마다 천차만별이니 먼저 메뉴와 무게를 확인하면 좋아요.
# - 추천 방문 컨셉: 점심에 해산물 모듬 or 해물찜, 저녁엔 시내 산책과 함께 가벼운 해산물 안주
#
# 2) 자갈치시장
# - 대표 메뉴 포인트: 활어회, 조개류 구이, 멍게/소라, 어묵 꼬치 등
# - 분위기: 현장감 있는 해산물 분주함 + 저렴한 가격대의 포장마차 스타일
# - 팁: 회 포장도 가능하고, 가게별로 양/생선 종류가 달라니 두세 군데 비교해 고르는 걸 추천
# - 추천 방문 컨셉: 시장 구경 + 바로 먹는 해산물 한 끼
#
# 3) 해운대 근처
# - 대표 메뉴 포인트: 해물탕/생선구이+밥, 조개구이, 해물파전
# - 분위기: 바다 전망과 함께 여유로운 분위기의 식당이 많아요
# - 팁: 해운대 해변가 인근은 주말에 붐빔. 좌석 확보를 원하면 예약 또는 이른 시간 방문이 좋음
# - 추천 방문 컨셉: 해변 산책 후 바다 보며 식사
#
# 4) 광안리
# - 대표 메뉴 포인트: 회/해물구이, 파전류, 조개구이
# - 분위기: 해질녘 야경 포인트가 많아 분위기 있는 식사에 좋아요
# - 팁: 바닷가가 가까워 바람이 강한 날은 따뜻한 국물 요리나 자리 선정이 중요
# - 추천 방문 컨셉: 바닷가 산책 + 가볍고 맛있는 해물 안주
#
# 5) 송도해수욕장
# - 대표 메뉴 포인트: 해물파전, 오징어볶음, 생선구이 모듬
# - 분위기: 가족 단위나 커플에게 편안한 캐주얼 레스토랑과 카페가 많아요
# - 팁: 해변가 카페에서 식사 후 산책으로 마무리하기 좋음
# - 추천 방문 컨셉: 해변 풍경과 함께 가벼운 식사
#
# 추가로 알아두면 좋은 맛집 포인트
# - 부산의 대표 조합: 해산물 + 막걸리, 또는 밀면과 돼지국밥으로 더운 날 시원하게 즐기기
# - 시장형 식당은 계절/날씨에 따라 메뉴 구성이 달라지므로 현장 메뉴판 확인이 중요
# - 맛집 찾는 팁: 구글/네이버 리뷰에서 최근 평점과 사진을 확인하고, 줄 서는 시간대(점심/저녁 피크타임)를 피하면 더 편해요
#
# 원하시면 바로 근처의 구체적인 식당 이름과 주소, 예상 가격대를 실시간으로 찾아 드릴게요. 다음 정보를 알려주시면 맞춤 목록을 만들어 드립니다.
# - 예산대(합리적/중급/럭셔리)
# - 선호 음식 타입(해산물 중심, 고기, 면류, 길거리 음식 등)
# - 동행 인원(혼자/연인/가족/아이 동반 여부)
# - 방문 예정 지역이나 경로(예: 남포동→해운대→광안리 같은 식으로 이동 계획)
#
# 또 하나의 빠른 옵션으로, 지금 바로 1일 맛집 코스로 3~4곳의 이름과 체류 시간까지 포함한 맞춤 리스트를 만들어 드릴 수도 있어요. 어떤 방식이 좋으신가요?

# %%
 
# memory.load_memory_variables({})#["history"]
# result = chain.invoke({"history": history, "input": user_input})
# print("result = ", result )
# Out:
# result =  content='좋아요! 바로 근처 맛집을 구체적으로 추천해 드릴게요. 다만 실제로는 현재 영업 여부나 좌석 상황이 바뀔 수 있어서, 최신 정보를 함께 확인해 드리려면 몇 가지를 알려주시면 좋습니다.\n\n원하시는 정보가 아래와 같아요:\n- 방문 지역/경로: 남포동, BIFF 광장, 자갈치시장, 해운대, 광안리 중 어디를 중심으로 볼까요?\n- 예산대: 합리적, 중급, 럭셔리 중 어떤가요?\n- 선호 메뉴 유형: 해산물 중심, 밀면/국밥, 고기/면류, 길거리 음식 등\n- 동행 인원 및 분위기: 솔로/커플/가족, 조용한 분위기 vs 활기찬 분위기\n- 특별 요청: 예약 필요 여부, 실내/야외 좌석, 알레르기나 피해야 할 음식\n\n원하시면 지금 바로 위치 기반으로 실시간으로 확인해 5곳 정도의 구체적인 가게 이름, 주소, 예상 가격대와 대표 메뉴까지 정리해 드릴게요. 어떤 방식으로 진행할까요? 또한 원하신다면 1일치 맛집 코스 3–4곳으로 바로 구성해 드릴 수도 있어요.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 2855, 'prompt_tokens': 2434, 'total_tokens': 5289, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2560, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DLj1nbyMlbEBCytO3grrVzNJbtUoX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d0ed5-32dd-7093-a21b-24dd85edb1d5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2434, 'output_tokens': 2855, 'total_tokens': 5289, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2560}}

# %% [markdown]
# 모델은 앞선 “부산 여행” 대화를 기억하고 자연스럽게 이어서 대답합니다.

# %%
memory.load_memory_variables({})['history']
# Out:
# [HumanMessage(content='부산 여행지 추천해줘.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='좋아요! 부산은 바다와 도시 문화가 함께 어우러진 곳이라 일정에 따라 다양한 매력을 즐길 수 있어요. 선호하는 분위기나 기간이 있으면 더 맞춤으로 골라 드릴게요. 우선 꼭 가볼 만한 곳과 간단한 코스 아이디어를 정리해볼게요.\n\n대표 명소 (꼭 가보면 좋은 곳)\n- 해운대 해수욕장 & 해운대 센텀: 국내에서 가장 유명한 해변. 모래사장 산책, 해변 카페, 야경까지 다양하게 즐길 수 있음. 여름에 행사가 많고 해수욕장 주변 시설이 잘 갖춰져 있어요.\n- 광안리 해수욕장 & 광안대교: 산책로와 카페가 많고, 저녁에 광안대교가 불빛으로 아름답게 빛나요. 야경 포인트로도 최적.\n- 남포동 / BIFF 광장 & 자갈치시장: 부산의 대표적인 먹거리 축제 공간. 자갈치시장에서는 신선한 해산물 구경·구매 가능, BIFF광장·국제시장 주변에서 길거리 음식 즐기기 좋습니다.\n- 감천문화마을: 알록달록한 계단식 마을의 예쁜 사진 포인트. 걷기 편하고, 작은 카페와 상점도 많아요.\n- 태종대: 해안 절벽과 등대, 바다 전망이 굉장히 아름다운 자연 명소. 유람선이나 산책로로 둘러보기 좋습니다.\n- 해동용궁사: 바다를 품은 사찰로, 가파르지 않은 길 따라 바다를 배경으로 산책하기 좋고 사진 찍기 좋습니다.\n- 범어사: 도심에서 가까운 고즈넉한 산사. 가벼운 트레킹 분위기로 방문하기 좋아요.\n- 금정산 / 금정산성: 하이킹을 즐기고 싶다면 추천. 멋진 산책길과 정상에서의 파노라마 뷰가 매력입니다.\n- 송도해수욕장 & 송도스카이워크: 비교적 조용한 해변과 바다 위 유리다리 같은 스카이워크가 있어 가족 단위나 커플 여행에 좋습니다.\n- 용두산공원 + 부산타워: 시내 전망을 한눈에 볼 수 있는 곳. 남포동 쪽 야경과 함께 가면 좋습니다.\n\n吃(음식) 포인트\n- 자갈치시장/국제시장 인근의 해산물 요리: 신선한 회, 조개구이, 해산물 grill 등 다양한 해산물 먹거리.\n- 밀면 & 돼지국밥: 부산 특유의 맛집을 찾으면 맛볼 만해요. 특히 밀면은 여름에 시원하게 즐기기 좋습니다.\n- 해산물 길거리 음식과 길거리 카페: 남포동·광복동 일대에서 다양한 간단한 간식과 커피를 즐길 수 있어요.\n\n계절별 팁\n- 봄/가을: 해동 용궁사, 금정산 트레킹, 감천문화마을 산책에 좋습니다. 쌀쌀한 아침 공기와 상쾌한 바다 바람.\n- 여름: 해운대·광안리 해변에서 물놀이, 해변 근처 야외 카페와 바비큐. 줄 서는 맛집보단 해변 근처를 노리면 더 수월.\n- 겨울: 실내 명소 위주로 조정. BIFF 광장, 남포동의 맛집 투어로도 충분합니다.\n\n샘플 일정 제안\n- 1일 코스 (도시 중심 가족/연인용)\n  1) 남포동-BIFF 광장 산책, 자갈치시장 구경\n  2) 부산타워/용두산공원에서 시내 전망\n  3) 해운대으로 이동해 해운대 해수욕장 산책 및 근처 카페\n  4) 저녁에 광안리에서 해넘이 감상 (가능하면 광안대교 야경)\n- 2일 코스 (해안과 문화 중심)\n  1) 감천문화마을 朝 산책\n  2) 해동용궁사 방문\n  3) 태종대 공원에서 바다 풍경 감상\n  4) 저녁에 남포동·국제시장 맛집 투어\n- 3일 코스 (하이킹/풍경)\n  1) 금정산 등산 트레킹 또는 금정산성 탐방\n  2) 송도해수욕장 산책 및 송도스카이워크\n  3) 해운대 근처 해변 카페에서 마무리\n\n교통 팁\n- 기본 교통수단: 부산 지하철 1호선/2호선 이용이 편리합니다. 주요 명소는 노선 간 환승으로 비교적 쉽게 도달.\n- 해변 지역은 버스나 택시 이용도 편리합니다. 특히 태종대, 해동용궁사, 금정산은 버스 연결이 다소 복잡할 수 있어 택시가 편리할 때가 있어요.\n- Seomyeon, 남포동, 해운대 등 중심지에서 출발하면 각 명소까지 이동 시간이 비교적 짧습니다.\n\n원하신다면 일정표를 날짜, 체류 기간, 예산, 선호 분위기(자연/문화/음식/가족 친화 등)에 맞춰 상세히 맞춤 설계해드릴게요. 몇 가지를 알려주실 수 있을까요?\n- 여행 기간(몇 박 며칠)\n- 선호하는 분위기나 관심 분야(해변/문화/맛집/야경/쇼핑 등)\n- 예산대(합리적/중급/럭셔리)\n- 동반 인원(혼자/연인/가족/아이 동반 여부)\n- 솔로여행인지, 사진 촬영을 많이 원하시는지 등\n\n필요하시면 위 정보에 맞춰 1일/2일/3일 코스의 상세 일정표와 추천 식당까지 포함해서 다시 정리해드릴게요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='그럼 그 근처 맛집은 어디야?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='좋아요! 부산은 지역마다 맛집 분위기도 다르고, 해산물 중심의 식당이 많아서 선택 폭이 넓어요. 아래는 지역별로 꼭 알아두면 좋은 맛집 포인트예요. 원하시면 예산이나 선호 메뉴에 맞춰 구체적인 식당 이름과 좌석 가능 여부까지 실시간으로 찾아드릴게요.\n\n1) 남포동/BIFF 광장 근처\n- 대표 메뉴 포인트: 신선한 해산물 회/굴냄비, 해물찜, 조개구이 등\n- 분위기: 활기찬 시장 분위기부터 깔끔한 해산물 전문점까지 다양\n- 팁: 시장 인근은 가격대가 가게마다 천차만별이니 먼저 메뉴와 무게를 확인하면 좋아요.\n- 추천 방문 컨셉: 점심에 해산물 모듬 or 해물찜, 저녁엔 시내 산책과 함께 가벼운 해산물 안주\n\n2) 자갈치시장\n- 대표 메뉴 포인트: 활어회, 조개류 구이, 멍게/소라, 어묵 꼬치 등\n- 분위기: 현장감 있는 해산물 분주함 + 저렴한 가격대의 포장마차 스타일\n- 팁: 회 포장도 가능하고, 가게별로 양/생선 종류가 달라니 두세 군데 비교해 고르는 걸 추천\n- 추천 방문 컨셉: 시장 구경 + 바로 먹는 해산물 한 끼\n\n3) 해운대 근처\n- 대표 메뉴 포인트: 해물탕/생선구이+밥, 조개구이, 해물파전\n- 분위기: 바다 전망과 함께 여유로운 분위기의 식당이 많아요\n- 팁: 해운대 해변가 인근은 주말에 붐빔. 좌석 확보를 원하면 예약 또는 이른 시간 방문이 좋음\n- 추천 방문 컨셉: 해변 산책 후 바다 보며 식사\n\n4) 광안리\n- 대표 메뉴 포인트: 회/해물구이, 파전류, 조개구이\n- 분위기: 해질녘 야경 포인트가 많아 분위기 있는 식사에 좋아요\n- 팁: 바닷가가 가까워 바람이 강한 날은 따뜻한 국물 요리나 자리 선정이 중요\n- 추천 방문 컨셉: 바닷가 산책 + 가볍고 맛있는 해물 안주\n\n5) 송도해수욕장\n- 대표 메뉴 포인트: 해물파전, 오징어볶음, 생선구이 모듬\n- 분위기: 가족 단위나 커플에게 편안한 캐주얼 레스토랑과 카페가 많아요\n- 팁: 해변가 카페에서 식사 후 산책으로 마무리하기 좋음\n- 추천 방문 컨셉: 해변 풍경과 함께 가벼운 식사\n\n추가로 알아두면 좋은 맛집 포인트\n- 부산의 대표 조합: 해산물 + 막걸리, 또는 밀면과 돼지국밥으로 더운 날 시원하게 즐기기\n- 시장형 식당은 계절/날씨에 따라 메뉴 구성이 달라지므로 현장 메뉴판 확인이 중요\n- 맛집 찾는 팁: 구글/네이버 리뷰에서 최근 평점과 사진을 확인하고, 줄 서는 시간대(점심/저녁 피크타임)를 피하면 더 편해요\n\n원하시면 바로 근처의 구체적인 식당 이름과 주소, 예상 가격대를 실시간으로 찾아 드릴게요. 다음 정보를 알려주시면 맞춤 목록을 만들어 드립니다.\n- 예산대(합리적/중급/럭셔리)\n- 선호 음식 타입(해산물 중심, 고기, 면류, 길거리 음식 등)\n- 동행 인원(혼자/연인/가족/아이 동반 여부)\n- 방문 예정 지역이나 경로(예: 남포동→해운대→광안리 같은 식으로 이동 계획)\n\n또 하나의 빠른 옵션으로, 지금 바로 1일 맛집 코스로 3~4곳의 이름과 체류 시간까지 포함한 맞춤 리스트를 만들어 드릴 수도 있어요. 어떤 방식이 좋으신가요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ### 코드 예시 2. 최근 대화만 유지 (Window Memory)

# %%
### 코드 예시 ① 기본 Buffer Memory
from langchain_openai import ChatOpenAI
from langchain_classic.memory import ConversationBufferWindowMemory
from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder

# 모델 선언
llm = ChatOpenAI(model="gpt-5-nano")

# 메모리 객체 생성 (대화 전체를 버퍼 형태로 저장)
memory = ConversationBufferWindowMemory(k=2, return_messages=True) # k=2 : 최근 2개의 기억만

# 프롬프트 템플릿
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 여행 전문가야. 사용자의 질문에 친절하게 답해줘."),
    MessagesPlaceholder(variable_name="history"),  # 이전 대화 삽입 위치
    ("human", "{input}")                           # 사용자 질문
]) 

# LCEL 체인 구성
chain = prompt | llm 

# 5️⃣ 연속 대화 시뮬레이션
inputs = ["부산 여행지 추천해줘.", "대한 민국의 수도는 어디야?", "서울의 인구는 몇명이야?", "내가 아까 추천해달라고 한 어행지는 어디야?" ]

for user_input in inputs:
    # 메모리 불러오기
    history = memory.load_memory_variables({})["history"]
    # 실행
    result = chain.invoke({"history": history, "input": user_input})
    # 결과 출력
    print(f"\n사용자: {user_input}\n 응답: {result.content}")
    # 메모리에 저장
    memory.save_context({"input": user_input}, {"output": result.content})
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21180\4293420745.py:10: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferWindowMemory(k=2, return_messages=True) # k=2 : 최근 2개의 기억만
# 사용자: 부산 여행지 추천해줘.
#  응답: 좋아요! 부산은 해변+도시문화가 동시에 매력적인 도시예요. 관심사(해변, 먹거리, 사진찍기, 역사 등) 알려주시면 더 맞춤으로 추천해줄게요. 우선 대표적인 명소와 코스 아이디어를 정리해봤어요.
#
# 추천 명소 (꼭 가봐야 할 곳)
# - 해운대 해수욕장 + 동백섬
#   - 한국에서 가장 유명한 해변 중 하나. 산책로가 잘 정비되어 있고 동백섬까지 이어진 산책로가 좋습니다. 여름 해수욕도 좋고, 겨울 바다 풍경도 매력적이에요.
# - 광안리 해변 + 광안대교 야경
#   - 넓은 해변에서 산책하기 좋고, 저녁에 광안대교가 조명으로 아름답게 빛나요. 야경 사진 명소로 인기.
# - 자갈치시장 + 국제시장 + BIFF 광장
#   - 부산의 먹거리 거리. 싱싱한 해산물 구경하고 바로 맛볼 수 있어요. 국제시장, BIFF 광장도 쇼핑과 먹거리로 활기찬 분위기.
# - 감천문화마을
#   - 알록달록 색색의 집과 벽화길이 사진 찍기 좋은 마을. 걷기 좋은 계단길이 매력 포인트.
# - 태종대
#   - 해안 절벽과 등대가 있는 자연 명소. 드라이브로도 좋고, 산책로와 전망대에서 바다 경치를 감상하기 좋습니다.
# - 남포동 + 남포동 야시장 포켓 코스
#   - 도심에서 맛집과 쇼핑을 한꺼번에 즐길 수 있는 지역. BIFF 거리 근처의 분위기도 좋습니다.
# - 범어사 & 금정산
#   - 서울 인근 도심과 다른 차분한 산사 분위기. 금정산 트레킹도 가능하고, 기분 전환에 좋아요.
# - 송도해상케이블카 + 송도해수욕장
#   - 바다 위를 가르는 케이블카와 함께 해변을 한꺼번에 즐길 수 있는 코스.
# - 해동용궁사
#   - 바다를 바라보며 고즈넉한 분위기의 사찰 방문.
#
# 3가지 루트 아이디어 (초보자용)
# - 1일 코스 (도심+해변 집중)
#   - 해운대 해수욕장 → 동백섬 산책 → 해운대 주변 카페/해산물 거리
#   - 오후: 광안리로 이동 → 광안대교 야경 감상
#   - 저녁: 남포동/국제시장으로 이동해 먹거리 탐방 또는 BIFF 광장 산책
# - 2일 코스 (문화+자연)
#   - 아침: 감천문화마을 산책 및 사진 찍기
#   - 점심: 자갈치시장/국제시장 근처에서 해산물 또는 지역 음식
#   - 오후: 태종대 방문 → 해안 산책로 걷기
#   - 저녁: 남포동 근처로 돌아와 야시장 분위기 즐기기
# - 당일치기 또는 더 여유롭게
#   - 오전: 송도해상케이블카 타고 바다 전망 감상
#   - 점심/오후: 송도해수욕장 산책 → APEC 누리마루 전망대/광복로 산책
#   - 저녁: 광안리로 돌아와 야경 감상 또는 해운대에서 마무리
#
# 이동 팁
# - 교통: 부산 지하철 1호선/2호선과 버스를 주로 이용하면 편합니다. 택시도 비교적 저렴한 편이므로 이동이 잦다면 택시 활용도 좋습니다.
# - 교통카드: 티머니(T-money) 같은 충전식 카드를 미리 준비하면 버스·지하철 이용이 편리해요.
# - 시기: 여름은 해수욕, 가을은 바다 경치와 야경, 봄은 벚꽃길(일부 장소에서 볼 수 있음)까지 계절마다 매력이 달라요.
# - 음식 포인트: 부산의 해산물은 신선도가 생명이에요. 자갈치시장이나 국제시장에서 싱싱한 해산물 요리, 밀면, 돼지국밥 같은 지역 음식도 꼭 경험해보세요.
#
# 원하는 분위기나 일정 기간(1~3일, 예산 선호 등)을 알려주면 더 구체적인 일정표와 장소 추천을 맞춤으로 구성해드릴게요. 어떤 느낌으로 즐기고 싶으신가요?
#
# 사용자: 대한 민국의 수도는 어디야?
#  응답: 대한민국의 수도는 서울(서울특별시)입니다. 서울 여행에 대해 궁금한 점이 있으면 알려주세요!
#
# 사용자: 서울의 인구는 몇명이야?
#  응답: 서울의 인구는 대략 9백만 명대예요. 최근 추계로는 약 9.5~9.8백만 명 정도로 보고됩니다(주민등록 인구 기준, 매년 소폭 변동).
#
# 정확한 최신 수치를 원하시면 공신력 있는 출처(통계청/서울시) 기준으로 업데이트해서 알려드릴게요. 여행 궁금한 점도 같이 도와드리겠습니다!
#
# 사용자: 내가 아까 추천해달라고 한 어행지는 어디야?
#  응답: 그 전에 어떤 여행지를 추천해 달라 하셨던 게 제 기억으로는 확실히 남아 있지 않아서요. 혹시 기억나는 키워드나 분위기를 조금만 알려주실 수 있을까요? 예를 들어 도시, 테마(문화/자연/해변/맛집 등), 기간, 예산 같은 것들이요. 바로 맞춤 추천 드릴게요.
#
# 참고로 지금 바로 몇 가지 인기 있는 옵션도 간단히 제안드려요:
# - 서울 도심 문화 체험코스: 경복궁 → 북촌 한옥마을 → 삼청동 카페 거리
# - 자연과 풍경 위주 코스: 가평/남이섬 혹은 설악산(속초)으로 당일치기 혹은 주말
# - 바다 도시 코스: 부산 해운대나 광안리 해변 + 자갈치 시장
# - 전통과 먹거리 in: 전주 한옥마을 + 비빔밥 체험
# - 제주도 대표 루트: 성산일출봉 + 우도 + 중문 관광단지
#
# 원하시면 이 중에서 바로 하나를 골라서 1박 2일 코스나 당일치기 일정으로 구체적으로 짜드릴게요. 기억나시는 장소나 선호를 알려주시면 더 정확히 맞춰드리겠습니다.

# %% [markdown]
# 이 방식은 단기 기억처럼 작동합니다.
# 오래된 대화는 자동으로 지워져 토큰 낭비를 줄이고 효율성을 높입니다.

# %% [markdown]
# ### 코드 예시 3. 이전 대화를 요약해서 저장 (ConversationSummaryMemory)

# %%
from langchain_openai import ChatOpenAI
from langchain_classic.memory import ConversationSummaryMemory
from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder

# 모델 선언
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7)

# 요약형 메모리 생성 — LLM이 과거 대화를 요약해 맥락을 유지
# 앞에 추가 소스
memory = ConversationSummaryMemory(llm=llm, return_messages=True)

# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 여행 플래너야. 사용자의 요구에 따라 가족 여행 일정을 제안해줘."),
    MessagesPlaceholder(variable_name="history"),  # 요약된 과거 대화 자동 삽입
    ("human", "{input}")                           # 현재 질문
])

# LCEL 체인 구성
chain = prompt | llm

# 연속 대화 시뮬레이션
inputs = [
    "이번 주말에 가족 여행지 추천해줘.",
    "지난번에 추천한 곳 중에 아이들이 놀기 좋은 곳은 어디였지?",
    "그럼 거기 일정표를 하루만 짜줘."
]

for user_input in inputs:
    history = memory.load_memory_variables({})["history"]
    result = chain.invoke({"history": history, "input": user_input})
    print(f"\n👤 사용자: {user_input}\n🤖 응답: {result.content}")
    memory.save_context({"input": user_input}, {"output": result.content})
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21180\2842420670.py:9: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryMemory(llm=llm, return_messages=True)
# 👤 사용자: 이번 주말에 가족 여행지 추천해줘.
# 🤖 응답: 좋아요! 이번 주말 가족 여행으로 가볍고 즐거운 곳들 몇 가지를 추천해드릴게요. 출발지는 보통 서울을 기준으로 생각했고, 아이들 연령대나 선호(자연/해변/문화/테마파크)에 따라 맞춤으로 더 추천해드릴 수 있습니다. 아래 중에서 취향에 맞는 코스를 골라 주시고, 출발지와 인원, 예산도 알려주시면 더 구체적인 일정으로 바로 짜 드릴게요.
#
# 추천 코스 1) 강릉 1박 2일(바다+카페거리)
# - 왜 좋나요: 해변 산책, 가족 친화적인 해산물 맛집, 아이들이 좋아하는 커피거리까지 한꺼번에 즐길 수 있어요.
# - 간단 일정 예시:
#   Day 1: 서울 출발 → 경포대 산책 → 점심: 해산물 혹은 닭강정 근처 맛집 → 안목 커피거리 카페 탐방 → 숙소 체크인 및 해변 산책
#   Day 2: 오대산 국립공원 짧은 트레킹 혹은 주문진 수산시장 방문 → 출발
# - 포인트: 해가 지는 시간의 바다 풍경이 아름다워 가족 사진도 잘 나오고, 아이들과 함께하기 좋아요.
#
# 추천 코스 2) 가평/청평 1박 2일(자연+레저)
# - 왜 좋나요: 아이들이 좋아하는 자연 체험과 레저 활동이 많고 이동 거리도 짧아요.
# - 간단 일정 예시:
#   Day 1: 서울 출발 → 남이섬 보트 타기 → 점심: 춘천 닭갈비(혹은 막국수) → 레일바이크 체험 → 숙소 체크인
#   Day 2: 수상레저/보트 체험 또는 아침 카페거리 산책 → 귀가
# - 포인트: 레일바이크나 보트 타는 시간이 아이들에게 즐거운 추억이 됩니다.
#
# 추천 코스 3) 파주 임진각/헤이리 예술마을 1박 2일(교육+문화)
# - 왜 좋나요: 아이들에게 역사적 시사점과 창의적 체험을 동시에 줄 수 있으며, 도심에서 벗어난 여유가 있어요.
# - 간단 일정 예시:
#   Day 1: 서울 출발 → 임진각 DMZ 지역 방문(전망대 등) → 점심: 파주 맛집 → 헤이리 예술마을 숙소 체크인 → 저녁
#   Day 2: 프로방스 마을 산책 → 파주 맛집 재방문 후 귀가
# - 포인트: 예술과 자연이 함께 어우러져 아이들과 어른 모두가 즐길 수 있습니다.
#
# 추천 코스 4) 전주 한옥마을 1박 2일(문화+맛집)
# - 왜 좋나요: 한국의 전통문화 체험과 함께 맛있는 음식이 많아 아이들 눈이 즐겁습니다.
# - 간단 일정 예시:
#   Day 1: 서울/수도권에서 KTX로 전주 도착 → 한옥마을 산책→ 저녁: 전주 비빔밥/콩나물국밥 등 지역 음식
#   Day 2: 전주향교/덕진공원 산책 → 전주 성곽 체험 → 귀가
# - 포인트: 전주의 분위기 속에 가족 사진 찍기 좋고, 아이들도 전통 놀이 체험 코스를 찾기 쉽습니다.
#
# 추가로 안내해주시면 더 맞춤화해 드려요
# - 출발지(도시하거나 구간)
# - 가족 구성원(아이 나이, 어른 수)
# - 선호 스타일(자연/바다/문화/테마파크/온천 등)
# - 예산 범위
# - 이동 수단(차로 이동 여부, 대중교통 선호)
#
# 원하시면 위의 코스 중 하나를 골라 2일간의 상세 시간표, 숙소 후보, 식당 추천, 필수 준비물 체크리스트까지 포함한 맞춤 일정으로 바로 짜 드릴게요.
#
# 👤 사용자: 지난번에 추천한 곳 중에 아이들이 놀기 좋은 곳은 어디였지?
# 🤖 응답: 좋아하는 활동에 따라 다르지만, 아이들이 “놀기”에 가장 잘 맞는 곳은 다음과 같아요.
#
# - Gapyeong/Cheongpyeong (자연+레저)
#   - 왜 좋나요: 넓은 자연 속에서 걷기, 자전거, 숲 체험, 아이들이 직접 만지며 놀 수 있는 공간이 많습니다. Nami Island, Petite France, Garden of Morning Calm 같은 곳이 있어 하루 종일 활동하기에 좋습니다.
#   - 추천 활동: 자전거 타기나 레일바이크, 아이들이 좋아하는 체험 프로그램, 자연 산책로.
#
# - Gangneung (해변+카페거리)
#   - 왜 좋나요: 해변에서 모래놀이와 물놀이를 쉽게 즐길 수 있고, 경포대/정동진 같은 곳에서 바다 풍경도 만끽 가능. 주변 카페거리도 아이 간식으로 즐거움 확보.
#   - 추천 활동: 해변 놀이, 모래성 쌓기, 산책로, 카페나 아이-friendly 맛집 방문.
#
# - Paju Imjingak/Heyri Art Village
#   - 왜 좋나요: 교육적·문화적 체험이 풍부합니다. 아이들이 미술관이나 체험 공간에서 창의적으로 놀 수 있어요.
#   - 주의점: 놀이 중심보다는 체험·전시 위주라 아이 관심이 오래 지속되려면 연령에 맞는 프로그램을 골라야 합니다.
#
# - Jeonju Hanok Village
#   - 왜 좋나요: 전통문화 체험과 맛집 체험이 집중되어 있어 색다른 놀이와 학습을 함께할 수 있습니다.
#   - 주의점: 놀이 공간이 넓지 않아 “놀기”보다는 문화·먹거리 체험 위주로 흘러갈 수 있습니다.
#
# 원하시면 아이들 연령대와 선호를 알려주면, 위 중 하나를 골라 2일 간의 맞춤형 일정(숙소 후보, 식당 추천, 필수 준비물 체크리스트 포함)으로 바로 작성해 드릴게요. 출발지는 서울 기준으로 맞춰드려요.
#
# 👤 사용자: 그럼 거기 일정표를 하루만 짜줘.
# 🤖 응답: 좋아요. 하나의 장소를 골라 1일 일정으로 바로 드려도 되고, 네 곳 중 하나를 선택해 바로 맞춤 일정으로 작성해 드릴 수도 있어요. 일단 네 곳 각각의 “하루 일정 예시”를 아래처럼 간단히 제시합니다. 아이 연령대에 따라 속도나 체험을 조정해 드릴 수 있어요. 어느 곳으로 진행할지 알려주시면 바로 세부 조정해 드릴게요. (서울 출발 기준으로 구성)
#
# 1) Gapyeong/Cheongpyeong – 자연+레저형, 아이들 숲 체험과 명소 조합
# - 오전
#   - 08:00 서울 출발
#   - 09:15 Gapyeong 도착 → 남이섬으로 이동 및 섬 탐방(산책, 자전거 체험 가능) - 2시간
# - 점심
#   - 12:00 남이섬 인근 식당 또는 Gapyeong 역 인근 식당
# - 오후
#   - 13:30 Petite France 방문(체험형 거리 산책, 사진 포인트)
#   - 15:00 Garden of Morning Calm으로 이동(자연 산책, 계절 정원 구경) - 1.5~2시간
# - 저녁/복귀
#   - 17:30 출발 → 19:30 서울 도착
# - 포인트
#   - 아이가 걷기 좋아하는 코스 위주로 구성. 자전거/승마 체험은 연령 제한 확인 필요.
#   - 비/더운 날은 대체 코스(실내 체험 위주)로 조정 가능.
# - 식당 아이디어
#   - 남이섬 근처 한식당, 또는 Gapyeong 내 맛집 추천 가능.
# - 체크리스트
#   - 가벼운 간식/물, 모자, 선크림, 편한 신발, 우천시 대비 우산/우의
#
# 2) Gangneung – 해변+카페거리형, 모래놀이와 바다 풍경
# - 오전
#   - 07:30 서울 출발 → 10:30 강릉 도착
#   - 10:45 경포해변에서 모래놀이 및 물놀이나 해변 산책
# - 점심
#   - 12:30 근처 해산물/두부요리 추천(초당두부, 해산물 요리)
# - 오후
#   - 14:00 Anmok Cafe Street 산책·간식
#   - 15:30 경포대 전망대 방문
# - 저녁/복귀
#   - 17:30 출발 → 20:30 서울 도착
# - 포인트
#   - 해변은 계절과 파도에 따라 이용 가능 시간 다름. 아이 모래놀이용 물놀이 물품(물놀이 장난감) 챙기기.
# - 식당 아이디어
#   - 경포 주변 해물/전복 요리 또는 초당두부 맛집
# - 체크리스트
#   - 모자/선크림, 물병, 여분의 옷, 비상약, 수영/물놀이 용품(필요 시)
#
# 3) Paju Imjingak/Heyri Art Village – 교육·문화 체험형
# - 오전
#   - 08:00 서울 출발 → 09:30 Imjingak Park 도착
#   - 10:30 평화누리공원/임진각 전시 관람(아이 연령에 맞춘 체험관 선택)
# - 점심
#   - 12:30 파주 맛집 혹은 Heyri 주변 카페/식당
# - 오후
#   - 14:00 Heyri Art Village로 이동 → 가족 체험관/전시 관람(체험 프로그램 사전 예약 권장)
#   - 16:00 Heyri 카페거리 산책 및 간식
# - 저녁/복귀
#   - 17:30 출발 → 19:30 서울 도착
# - 포인트
#   - 놀이 중심보다는 체험/전시 위주라 연령별 체험 프로그램 선택이 관건. 미리 일정 확인 추천.
# - 식당 아이디어
#   - Heyri Art Village 내 카페/작은 중국집, 파주 유명 먹거리
# - 체크리스트
#   - 체험 예약 확인, 날씨에 맞는 옷차림, 간식/물
#
# 4) Jeonju Hanok Village – 전통문화 체험 중심
# - 오전
#   - 07:30 서울 출발 → 10:30 전주 도착
#   - 11:00 한옥마을 산책 및 전통문화 체험(한지공예, 종이접기 등)
# - 점심
#   - 12:30 전주비빔밥 등 전주 대표 음식 맛집 추천
# - 오후
#   - 14:00 남부시장 산책 및 간식
#   - 15:30 카페 타임 또는 전주 전통차 체험
# - 저녁/복귀
#   - 17:30 출발 → 21:00 서울 도착
# - 포인트
#   - 놀이 공간이 넓지 않으니 culture 중심 활동으로 흐름 조정. 아이가 지치지 않도록 짧은 걷기 코스 위주로.
# - 식당 아이디어
#   - 전주 비빔밥, 콩나물국밥 등 현지 맛집
# - 체크리스트
#   - 실내 체험 예약 여부 확인, 가방 가볍게, 비상 의약품
#
# 원하시는 장소를 골라 주시면:
# - 아이의 연령대에 맞춘 체험 선택지 구체화
# - 이동 수단(자가용/대중교통)에 맞춘 구체 시간표
# - 숙소 추천(근처 숙소 후보)과 함께 간단한 식당 추천 목록
# - 필수 준비물 체크리스트를 다듬어 드릴게요. 또한 출발 시각을 서울 기준으로 바꿔드리거나, 특정 날짜에 맞춰 티켓/예약이 필요하면 바로 반영해 드리겠습니다. 어떤 장소로 진행할까요?

# %%
# 현재까지의 요약본 확인
print(memory.buffer)
# Out:
# 그다음 대화에서 인간은 하루 일정표를 원했고, AI는 Gapyeong/Cheongpyeong, Gangneung, Paju Imjingak/Heyri Art Village, Jeonju Hanok Village 각각에 대해 '하루 일정 예시'를 제시했다. 각 일정은 서울 출발 기준으로 오전 시작과 주요 방문지/활동, 점심·저녁 계획, 귀가 시간까지 포함되며, 아이 연령대에 따른 속도 조정이나 실내 체험 대안 가능성 같은 포인트도 함께 제시됐다. 또한 놀이 중심보다는 체험·전시·문화 중심으로 구성된 점이 강조되었고, 최종 선택 시 세부 조정, 이동 수단, 숙소 후보, 식당 추천, 필수 준비물 체크리스트를 맞춤으로 제공하겠다고 안내했다. 어떤 장소로 진행할지 선택해 주면 된다.

# %% [markdown]
# 이 방식은 LLM이 이전 대화를 스스로 요약하여 핵심 맥락을 유지합니다.
# 수백 문장의 대화도 핵심 내용만 남기기 때문에 효율적입니다.

# %% [markdown]
# **핵심 정리**
# | Memory 타입 | 특징 | 사용 목적 |
# |--------------|--------|-------------|
# | **BufferMemory** | 모든 대화를 그대로 저장 | 짧은 대화, 디버깅용 |
# | **WindowMemory** | 최근 N개의 대화만 유지 | 실시간 채팅, 효율성 |
# | **SummaryMemory** | 이전 대화를 요약해서 유지 | 긴 대화 맥락 유지형 챗봇 |

# %% [markdown]
# 🔹 실습 : 아래 조건을 만족하는 “나만의 대화형 여행 상담 챗봇”을 만들어보세요.
#
# 당신은 AI 여행 비서 트래블GPT 입니다.
# 고객이 여러 도시를 순서대로 여행하면서 맞춤 일정·숙소·음식을 요청할 때,
# 이전 대화 내용을 기억하며 연결된 제안을 해주는 지능형 여행 어시스턴트를 구현하세요.
#
# 1. ChatOpenAI(model="gpt-5-nano") 사용
# 2. ConversationSummaryMemory로 요약 기반 대화 기억 구현
# 3. 답변에 반드시 "이전 여행 내용을 바탕으로 추천드리면..." 이라는 문구 포함
#   - 예시 : 이전 여행 내용을 바탕으로 추천드리면, 여수에서는 해상케이블카와 낭만포차거리를 꼭 가보세요.
# 4. 대화 시나리오:
#   - 사용자가 “부산 → 여수 → 강릉” 순으로 도시를 이동
#   - 챗봇은 이전 도시에서 한 활동을 기억하고 “연결된 여행 루트”나 “테마별 추천(가족/커플/힐링)”을 제안할 것
#
# 예시 시나리오
# ```bash
# 사용자: 이번 주말엔 부산 갈 건데 가족 여행지 좀 추천해줘.
# AI: 부산의 해운대, 아쿠아리움이 가족 단위로 인기예요!
#
# 사용자: 이번엔 여수로 가볼까?
# AI: 이전 여행 내용을 바탕으로 추천드리면, 부산의 해변 감성에 이어 여수에서는 바다 전망 케이블카와 낭만포차를 즐기세요.
#
# 사용자: 그럼 마지막은 강릉이 좋을까?
# AI: 이전 여행 내용을 바탕으로 추천드리면, 강릉에서는 여수보다 조용한 힐링 카페 거리와 바다 일출 코스를 권합니다.
# ```

# %%
from langchain_openai import ChatOpenAI
from langchain_classic.memory import ConversationSummaryMemory
from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder

# 1. 모델 선언
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7)

# 2. 요약형 메모리 생성
memory = ConversationSummaryMemory(
    # TODO: 필요한 인자를 채워보세요.
)

# 3. 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_messages([
    ("system",
     # TODO: 트래블GPT의 역할과 반드시 포함할 문구 조건을 작성해보세요.
    ),
    # TODO: 이전 대화(history)가 들어갈 자리를 추가해보세요.
    ("human", "{input}")
])

# 4. LCEL 체인 구성
chain = ...

# 5. 대화 시나리오
inputs = [
    "이번 주말엔 부산 갈 건데 가족 여행지 좀 추천해줘.",
    "이번엔 여수로 가볼까?",
    "그럼 마지막은 강릉이 좋을까?"
]

# 6. 연속 대화 실행
for user_input in inputs:
    history = ...
    result = ...
    print(f"\n사용자: {user_input}\n트래블GPT: {result.content}")
    memory.save_context(...)

# 7. 선택: 요약된 메모리 확인
print(memory.buffer)

# %% [markdown]
# <details>
# <summary>정답 보기</summary>
#
# ```python
# from langchain_openai import ChatOpenAI
# from langchain_classic.memory import ConversationSummaryMemory
# from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder
#
# # 모델 선언
# llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7)
#
# # 메모리 생성 — 이전 대화를 요약하며 맥락 유지
# memory = ConversationSummaryMemory(llm=llm, return_messages=True)
#
# # 프롬프트 템플릿 정의
# prompt = ChatPromptTemplate.from_messages([
#     ("system",
#      "너는 여행 비서 트래블GPT야. "
#      "사용자의 여행 루트를 기억하고, 이전 여행 내용을 바탕으로 다음 도시를 추천해줘. "
#      "답변에는 반드시 '이전 여행 내용을 바탕으로 추천드리면,' 이라는 문구를 포함해야 해."),
#     MessagesPlaceholder(variable_name="history"),
#     ("human", "{input}")
# ])
#
# # LCEL 체인 구성
# chain = prompt | llm
#
# # 대화 시나리오
# inputs = [
#     "이번 주말엔 부산 갈 건데 가족 여행지 좀 추천해줘.",
#     "이번엔 여수로 가볼까?",
#     "그럼 마지막은 강릉이 좋을까?"
# ]
#
# # 연속 대화 시뮬레이션
# for user_input in inputs:
#     history = memory.load_memory_variables({})["history"]
#     result = chain.invoke({"history": history, "input": user_input})
#     print(f"\n사용자: {user_input}\n트래블GPT: {result.content}")
#     memory.save_context({"input": user_input}, {"output": result.content})
#
# # 대화 요약 확인 (선택)
# print("\n요약된 Memory Buffer:")
# print(memory.buffer)
# ```
# </details>

# %%
from langchain_openai import ChatOpenAI
from langchain_classic.memory import ConversationSummaryMemory
from langchain_core.prompts  import ChatPromptTemplate, MessagesPlaceholder

# 모델 선언
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.7)

# 메모리 생성 — 이전 대화를 요약하며 맥락 유지
memory = ConversationSummaryMemory(llm=llm, return_messages=True)

# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_messages([
    ("system",
     "너는 여행 비서 트래블GPT야. "
     "사용자의 여행 루트를 기억하고, 이전 여행 내용을 바탕으로 다음 도시를 추천해줘. "
     "답변에는 반드시 '이전 여행 내용을 바탕으로 추천드리면,' 이라는 문구를 포함해야 해."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

# LCEL 체인 구성
chain = prompt | llm

# 대화 시나리오
inputs = [
    "이번 주말엔 부산 갈 건데 가족 여행지 좀 추천해줘.",
    "이번엔 여수로 가볼까?",
    "그럼 마지막은 강릉이 좋을까?"
]

# 연속 대화 시뮬레이션
for user_input in inputs:
    history = memory.load_memory_variables({})["history"]
    result = chain.invoke({"history": history, "input": user_input})
    print(f"\n사용자: {user_input}\n트래블GPT: {result.content}")
    memory.save_context({"input": user_input}, {"output": result.content})

# 대화 요약 확인 (선택)
print("\n요약된 Memory Buffer:")
print(memory.buffer)
# Out:
# 사용자: 이번 주말엔 부산 갈 건데 가족 여행지 좀 추천해줘.
# 트래블GPT: 이전 여행 내용을 바탕으로 추천드리면, 이번 주말 부산 가족 여행으로 아래 코스를 고려해보세요.
#
# 주요 가족 친화 장소
# - 해운대 해수욕장 + 동백섬 산책로
#   - 왜 좋나요: 넓은 모래사장과 평탄한 산책로, 아이들과 함께 바다 풍경을 따라 걷기 좋음. 누리마루 APEC 하우스 근처에서 전망도 멋짐.
#   - 대략 소요: 2시간 전후
# - 부산 아쿠아리움
#   - 왜 좋나요: 실내에서 다양한 해양생물을 가까이서 볼 수 있어 비 오는 날이나 아이들이 지루해할 때도 좋아요.
#   - 대략 소요: 1.5~2시간
# - 광안리 해수욕장 + 광안대교 야경
#   - 왜 좋나요: 저녁에 멋진 야경과 여유로운 해변 산책이 가능. 아이들이 간단한 놀이를 즐기기에도 무난.
#   - 대략 소요: 해안 산책 1~2시간
# - 감천문화마을
#   - 왜 좋나요: 알록달록한 벽화 골목길이 아이들에게도 재미있고, 사진 찍기 좋은 포인트가 많아요.
#   - 대략 소요: 1.5~2시간
# - 용두산공원 + 부산타워
#   - 왜 좋나요: 도심 속 전망대에서 부산 시내를 한눈에 볼 수 있음. 걷기 편한 동선이 많고 짧게 끝낼 수 있어 가족에 적합.
#   - 대략 소요: 1~1.5시간
#
# 샘플 2일 일정 제안
# - 1일차(해운대 기반)
#   - 오전: 해운대 해수욕장 산책 → 동백섬 산책로 걷기
#   - 점심: 해운대 인근 해산물이나 밀면 등 현지 식사
#   - 오후: 부산 아쿠아리움 관람
#   - 저녁: 광안리로 이동해 산책 및 야경 감상
# - 2일차
#   - 오전: 감천문화마을 방문
#   - 점심: 남포동/깡통시장 근처 간단한 현지 음식
#   - 오후: 용두산공원 및 부산타워에서 도시 전경 감상
#   - 선택지: 시간 여유가 있다면 비슷한 거리의 Beomeosa Temple이나 태종대 코스를 짧게 추가도 가능
#
# 현장 팁
# - 교통: 주말은 차가 붐빌 수 있어 가능하면 대중교통(지하철 2호선/1호선, 버스) 이용을 권합니다.
# - 주차: 해운대·광안리 지역은 주차가 어려운 경우가 많아 대중교통이 편리합니다.
# - 비상 크래들: 아이들 간식과 물, 비올 경우를 대비한 얇은 우비나 우산 챙기기.
# - 예매: 아쿠아리움이나 인기 장소는 사전 예매가 편합니다.
#
# 추가로 도움이 되려면 가족 구성(연령대, 유모차 여부, 식사 선호도, 활동 선호도)과 예산 범위를 알려주시면, 그에 맞춘 더 자세한 일정표를 만들어 드릴게요.
#
# 사용자: 이번엔 여수로 가볼까?
# 트래블GPT: 이전 여행 내용을 바탕으로 추천드리면, 여수도 가족 단위로 즐기기 딱 좋은 해안 도시예요. 2일짜리 가족 친화 일정으로 제안드립니다.
#
# 2일간의 가족 여행 코스 (여수)
#
# - Day 1: Odongdo Island + 해안 산책 + 야경 포인트
#   - 오전: Odongdo Island(오동도) 산책로 따라 seawall와 소나무 숲 걷기. 봄에는 매화·동백, 가을에는 억새가 아름답습니다. 등대와 해안 풍경 포인트에서 사진도 많이 남겨보세요.
#   - 점심: Odongdo 인근 해산물 식당이나 Yeosu Fish Market에서 신선한 해물 요리 맛보기.
#   - 오후: Yeosu Cable Car 탑승으로 바다 위와 시내 풍경 감상. 탑승 후 Dolsan Park으로 이어지는 경치 좋은 코스로 이동.
#   - 해질 무렵: Dolsan Bridge 근처에서 석양과 야경 감상. 아이들도 무리 없이 걷기 좋은 산책로에요.
#   - 저녁: 시내로 돌아와 근처 해물 요리 전문점이나 시장가에서 간단하게 마무리.
#
# - Day 2: Aqua Planet Yeosu + Oedo Botania(Optional) + 여유로운 마무리
#   - 아침: Aqua Planet Yeosu(아쿠아 플래닛 여수) 방문. 아이들이 좋아하는 대형 아쿠아리움으로 실내 활동이라 날씨 영향 없이 즐길 수 있어요.
#   - 점심: 인근에서 간단한 점심 or 시장식
#   - 오후: 원하시면 Oedo Botania로 가보세요. 여수 항구 근처의 작은 섬으로, 대형 정원과 아름다운 바다 풍경을 함께 즐길 수 있습니다. 페리를 이용해 짧은 코스로 다녀올 수 있어 가족 단위로 좋습니다.
#   - 대안 활동(날씨에 따라): Yeosu Rail Bike(해안 레일 바이크) 타기, 또는 시내의 Yeosu Jungang Market에서 간식 핫스팟 탐방.
#   - 저녁: 여수 시내에서 가벼운 해산물 저녁으로 마무리하거나, 공항/버스 터미널 방향으로 이동하기 전 마지막 간식.
#
# 실전 팁
# - 사전 예약 권장 품목: Aqua Planet Yeosu 입장권, Oedo Botania 페리/입장권, Rail Bike. 계절과 날씨에 따라 운영시간이 변동될 수 있어 최소한 당일 아침 확인 및 예매를 권합니다.
# - 교통/주차: 여수 시내 중심가와 오동도 일대는 주차 공간이 한정될 수 있어 주차 가능 시간대를 노려 방문하시고, 대중교통 이용 시 여수 시내버스 노선도 편합니다. 가족 단위라면 택시 이용도 비교적 수월합니다.
# - 아이를 위한 준비물: 간식, 물병, 우천 대비 우산/비옷, 편한 신발, 짧은 휴식 시간 확보(아이 피로도 관리).
# - 비가 올 경우의 대체 코스: Indoor 위주로 Aqua Planet, 오동도 내 짧은 산책 코스 대체; 실내 전시관이나 해양관계 시설 위주로 동선 변경 가능.
#
# 다음 도시도 여수로 결정한 이유를 토대로, 가족 구성원(연령대, mobility, 예산, 선호 활동)을 알려주시면 더 맞춤형 2박 3일 일정이나 주차별 상세 루트를 만들어 드릴게요. 예를 들어 2박 3일로 확장하거나, 아이가 어리면 더 느긋한 페이스로 조정해 드립니다. 원하시는 기간과 가족 구성 정보를 공유해 주세요.
#
# 사용자: 그럼 마지막은 강릉이 좋을까?
# 트래블GPT: 이전 여행 내용을 바탕으로 추천드리면, 강릉은 마지막 여행지로도 아주 매력적입니다. 동해 바닷바람을 느끼며 느긋하게 마무리하기에 좋고, 아이들과 함께하기 좋은 해변 놀이터, 맛집, 문화유적지가 골고루 있어 가족 여행에 최적화된 코스예요.
#
# 강릉이 좋은 이유
# - 해변과 바다 풍경이 한결 여유롭고 아이들과 걷기 좋은 산책로가 많아요(경포대, 경포호, 안목해변 등).
# - 가족 친화적인 체험이 많습니다. 정동진 모래사장 산책, 오죽헌/선교장 같은 문화유적, 낙산사 같은 아름다운 절경까지 모두 쉬운 동선으로 묶을 수 있어요.
# - 커피문화도 쉽게 즐길 수 있고, 아이와 함께하는 가벼운 카페 타임이 부담 없이 가능해요(안목해변 카페거리).
# - 계절에 따라 다양한 활동이 가능하고, 비가 와도 실내 명소(전시관, 역사 유적지, 카페)로도 충분히 즐길 수 있습니다.
#
# 제안하는 2박 3일 가족 여행 일정 (강릉, 초당두부 포함 추천)
# Day 1: 경포 일대와 커피거리
# - 아침/오전: 경포대와 경포호수 산책, 해변 산책로에서 손잡고 여유롭게 걷기
# - 점심: 경포 주변의 해산물 코스 or 초당두부 마을에서 점심
# - 오후: 안목해변 카페거리에서 아이 간식과 휴식
# - 저녁: 강릉 시내 또는 경포 주변 해물 요리 맛집
# - 노을/저녁 간단 활동: 경포대에서 짧은 노을 감상
#
# Day 2: 문화 유적과 동해 바다의 매력
# - 아침: 호텔/숙소 근처에서 여유로운 아침
# - 오전: 오죽헌(신사임당의 집) 방문 + 근처 전통문화 체험
# - 점심: 초당두부 또는 강릉식 해산물 점심
# - 오후: 낙산사 혹은 낙산 해수욕장 방문, 낙산도립공원 산책
# - 저녁: 강릉 시내로 돌아와 지역 맛집 탐방
# - 선택 옵션: 정동진으로 이동해 모래사장 산책이나 바다 풍경 감상
#
# Day 3 (선택형): 해변 마무리 + 여유로운 마감
# - 아침: 경포 주변 다시 한 번 산책, 아이 간식 타임
# - 오전/오후 중 선택:
#   - 낭만적인 해안 트레일 따라 짧은 산책 + 근처 카페 체험
#   - 양양 인근 하조대 해변 방문(차로 당일치기 가능)
#   - 또는 아쉬운 비를 피해 실내 체험으로 변환: 어린이 박물관, 전시관 방문
# - 점심/마감: 강릉의 마지막 맛집에서 점심 후 귀가
#
# 실무 팁
# - 이동: 가족 단위라면 차로 이동하거나 자가용/렌트카가 편합니다. 대중교통도 가능하지만 동선이 길어지는 날이 많아 일정 관리가 중요합니다.
# - 주차/동선: 경포대·안목해변 인근은 주차가 혼잡할 수 있어 이른 시간대 주차를 노리거나, 숙소를 경포권으로 잡으면 편합니다.
# - 주요 입장권/예약: 오죽헌·선교장 등은 예약 필요는 아니지만, 인기가 많아 대기 시간에 여유를 두는 게 좋습니다. 낙산사나 해변 트레킹은 계절에 따라 일교차에 주의.
# - 비가 올 경우 대처: 실내 위주 코스로 전환하기 쉬운 강릉의 카페 문화와 문화유산 방문으로도 충분히 즐길 수 있습니다.
# - 아이를 위한 팁: 간식과 물, 가벼운 놀거리(공부볼거리) 챙기고, 짧은 휴식 시간을 매일 포함시켜 주세요. 무리 없이 하루 2~3시간마다 휴식 추천.
#
# 다음 단계 제안
# 이 동선을 바탕으로 2박 3일 맞춤 일정으로 더 세밀하게 조정해 드릴 수 있어요. 가족 구성(아이 연령, 보행 가능 여부, 예산), 선호 활동(해수욕, 문화체험, 맛집 위주, 카페 체험 등)을 알려주시면 속도와 강도에 맞춘 상세 일정표를 바로 만들어 드리겠습니다. 그리고 다음 도시를 강릉으로 확정하신다면, 경로상 최적의 이동 수단과 하루 일정의 소요 시간까지 반영해 1페이지짜리 최적 루트도 함께 드릴게요.
#
# 요약된 Memory Buffer:
# New summary:
# The human proposes Gangneung as the final destination for a weekend family trip. Building on the prior Busan→Yeosu plan, the AI endorses Gangneung as a relaxed coastal option with kid-friendly beaches, easy walking routes, coffee culture, and cultural sites, making it ideal for families. It offers a 2-night-3-day itinerary: Day 1 around the Gyeongpo area and Anmok Coffee Street with a beach walk, lunch featuring seafood or Chodang tofu, and sunset; Day 2 focuses on Ojukheon and SeonggyoJang (traditional culture experiences) in the morning, followed by Naksan Temple or Naksan Beach and Naksan Provincial Park in the afternoon, with an optional Jeongdongjin visit for coastal views; Day 3 provides flexible options such as a coastal trail or a Yangyang-area Hajo-dae Beach trip, or indoor kid-friendly venues if rain; Practical tips cover driving/rental car, parking near Gyeongpo, pre-bookings for Ojukheon, SeonggyoJang, and Naksan, weather contingency, and packing essentials for kids; The AI invites tailoring based on family details (ages, mobility, budget, interests) and can output a refined 2N3D schedule or a 1-page optimal route once Gangneung is confirmed.
